# %% [markdown]
# ## Использование баз данных в Питоне
#
# Если вы хотите повторить код, который написан в этой тетрадке, то предполагается, что у вас на локальной машине стоит MySQL-сервер (я буду использовать Docker) и MySQL-клиент для Питона.
#
# Если вы предпочитаете работать через Docker, то можно использовать следующую команду.
#
# `docker run --rm -p 33061:3306 -e MYSQL_ROOT_PASSWORD=qwertbvcxz mysql`
# - run - запустить;
# - --rm - удалить контейнер после завершения;
# - -p 33061:3306 - всю информацию с порта 3306 контейнера передавать на порт 33061 компьютера и наоборот.
# - -e MYSQL_ROOT_PASSWORD=qwertbvcxz - передать параметр `MYSQL_ROOT_PASSWORD` со значением `qwertbvcxz` в контейнер (установи мне пароль от рута в значение qwertbvcxz);
# - mysql - какой контейнер запускать.
#
# Если у вас уже установлен MySQL сервер, то можно работать с ним через порт 3306 (по умолчанию). Так как я планирую работать через Docker, то и порт у меня будет установлен 33061 (указанный в командной строке).
#
# Создание базы я буду делать через MySQL Workbench (скачивается [отсюда](https://dev.mysql.com/downloads/workbench/)).
#
# Чтобы поставить себе библиотеки для Питона, работающие с MySQL, надо выполнить команду
# `pip3 install mysql-connector-python`

# %%
import re

# %%
# Если не хочется долгих экспериментов, в папке лежит сокращенная версия файла с новостями:
# summer22.txt
with open("data/lenta2018_summer22.txt", encoding="utf-8") as newsfile: # Файл с новостями.
    text_news = [(n.split("-----\n")[0].split('\n')[0], 
                  n.split("-----\n")[0].split('\n')[1], 
                  n.split("-----\n")[1]) for n in newsfile.read().split("=====\n")[1:]]

# %%
text_news[:5]
# Out:
# [('«Королева дерьмовых роботов» перенесла операцию на мозге',
#   '2018/06/01',
#   'Шведская YouTube-знаменитость Симона Герц (Simone Giertz), прославившаяся необычными изобретениями, перенесла операцию. Об этом рассказали ее представители в Twitter. Еще в конце апреля девушка сообщила подписчикам о недуге. Оказалось, что у нее в мозге обнаружили доброкачественную опухоль размером с мяч для гольфа. Блогер даже дала ей имя, назвав новообразование Брайаном.  Герц сильно переживала перед хирургическим вмешательством. В одном из предоперационных видео она говорила, что очень напугана. Однако врачи быстро удалили опухоль и спасли девушке жизнь. «Симона вышла из хирургии, и ее врачи очень довольны тем, как все прошло. Она проспала достаточно долго, чтобы сделать неуместную шутку, так что все хорошо», — говорится на ее странице в Twitter.  27-летняя изобретательница из Стокгольма прославилась несколько лет назад, показывая подписчикам свои бесполезные изобретения. Например, Герц демонстрировала самодельный будильник, к которому приделана резиновая рука, избивающая спящего человека. Кроме того, девушка создавала автоматизированную машину для наливания молока в тарелку с хлопьями. Сама Герц называет себя «королевой дерьмовых роботов», на ее канал подписаны более миллиона пользователей.\n'),
#  ('У Су-57 нашли «тайные ноу-хау»',
#   '2018/06/01',
#   'Перспективный российский многофункциональный истребитель пятого поколения Су-57 не имеет мировых аналогов и о нем не могут судить «дилетанты из СМИ», поскольку его «ноу-хау являются тайной», о которых знают лишь «профессионалы, испытатели, военное руководство страны». Такую точку зрения РИА Новости высказал летчик-испытатель Магомед Толбоев. «Ни на одном самолете еще никогда не удавалось добиться того, чтобы на крейсерских сверхзвуковых скоростях (1600 
#   'Более 100 жителей Киева перекрыли проспект Григоренко в четверг вечером после ДТП, в котором пострадал 13-летний ребенок. Об этом сообщает «Интерфакс-Украина». По утверждению очевидцев, пересекавшего пешеходный переход мальчика на велосипеде сбил автомобиль из кортежа президента Петра Порошенко. В администрации главы государства эту информацию опровергли. Позднее пресс-служба Национальной полиции Киева выпустила заявление, в котором признала ответственность за случившееся, уточнив, что автомобиль принадлежит правоохранительным органам и в момент ДТП следовал на «спецзадание». Находившиеся в машине полицейские прошли тест на алкоголь в присутствии понятых, прибор не выявил следов этанола. В настоящее время водитель направлен на наркологическую экспертизу. 6 марта кортеж Порошенко сбил пожилого мужчину, который пытался перебежать дорогу. Пострадавший, после того как пришел в сознание, признался в нарушении правил дорожного движения.\n')]

# %% [markdown]
# Теперь подключим библиотеку для работы с СУБД.

# %%
import mysql.connector

# %% [markdown]
# Для того, чтобы подключиться к базе данных создаем соедиение при помощи метода `connect`. В него необходимо передать следующие параметры: адрес (или название) сервера, на котором стоит СУБД; базу данных (схему), с которой мы собираемся работать; логин пользователя, имеющего право работать с этой базой; его пароль.
#
# Здесь я не указываю к какой базе мы подключаемся, так как считаю, что этой базы еще нет.

# %%
con = mysql.connector.connect(host='127.0.0.1', port=33061, user='root', password='qwertbvcxz')

# %% [markdown]
# Объект con теперь позволяет работать с соединением. С его помощью создадим курсор, который будет отправлять SQL-запросы и получать их результаты. Параметр dictionary=True означает, что результаты будут возвращаться в виде словаря. По умолчанию его значение равно False, то есть результаты будут возвращаться в виде списка.
#
# В первом случае выборка из базы данных будет возвращаться в виде списока записей, каждая из которых представляется словарем. Ключами в этом словаре будут имена полей, к которым будут привязаны соответствующие значения. Во втором случае получится список списков.

# %%
cur=con.cursor(dictionary=True)

# %% [markdown]
# Создадим базу `texts4experiments`, в которую будем складывать информацию о текстах.

# %%
cur.execute("CREATE DATABASE texts4experiments /*!40100 DEFAULT CHARACTER SET utf8mb4 COLLATE utf8mb4_0900_ai_ci */ /*!80016 DEFAULT ENCRYPTION='N' */;")

# %% [markdown]
# Теперь подключился к базе еще раз, указав название базы данных, которую мы будем использовать по умолчанию.

# %%
con = mysql.connector.connect(host='127.0.0.1', port=33061, database='texts4experiments', user='root', password='qwertbvcxz')

# %%
cur=con.cursor(dictionary=True)

# %%
cur.execute("""CREATE TABLE text_table (
  id_text INT NOT NULL AUTO_INCREMENT,
  header VARCHAR(256) NULL,
  article VARCHAR(9192) NULL,
  art_date VARCHAR(10) NULL,
  PRIMARY KEY (id_text),
  UNIQUE INDEX id_text_UNIQUE (id_text ASC) VISIBLE);
""")

# %% [markdown]
# Теперь нам надо загрузить новости в таблицу базы данных. Перебираем все заметки и вставвляем их в таблицу при помощи <a href="https://ru.wikipedia.org/wiki/Insert_(SQL)">INSERT</a>. После каждого оператора вызываем операцию подтверждения транзакции. Сама транзакция открывается автоматически при отправке SQL-запроса на сервер (если не была открыта ранее вручную при помощи метода <a href="https://dev.mysql.com/doc/connector-python/en/connector-python-api-mysqlconnection-start-transaction.html">start_transaction()</a>). Все присылаемые данные СУБД не записывает в таблицу, а кеширует. Если в какой-то момент мы решим, что все действия с начала транзакции необходимо отменить, необхододимо вызвать метод rollback. Если все изменения должны быть применены удачно, требуется вызвать commit. Мы будем вызывать commit после каждого SQL-запроса, хотя сервер будет работать быстрее, если мы будем вызывать его, например, раз в десять запросов.<br>
# В выводе можно увидеть запросы, которые не могут быть выполнены. Заметьте, что мы заменили все апострофы в тексте на \' чтобы они не считались СУБД как конец строки, добавляемой в базу. Однако текст содержит символы, которые СУБД воспринимает как нечитаемые. Чтобы побороть этот факт можно закодировать текст в кодировку <a href="https://docs.python.org/2/library/base64.html">Base64</a>, а при получении данных из СУБД раскодировать их обратно (или кодировать только проблемные строки, добавляя в начало определенный префикс).<br>
# Но мы просто заменим символ апострофа ' на \\'.
#
# SQL-запрос можно формировать динамически - это всего лишь строка.

# %%
# %%time
for a in text_news[:1000]:
    
    head = a[0].replace("'", "\\'")
    art = a[2].replace("'", "\\'")
    head = a[0].replace('"', '\\"')
    art = a[2].replace('"', '\\"')
    
    try:
        #sss = "INSERT INTO text_table (header, article, art_date) VALUES ('"+head+"','"+art+"', '"+a[1]+"')"
        sss = f"INSERT INTO text_table (header, article, art_date) VALUES ('{head}', '{art}', '{a[1]}')"
        cur.execute(sss)
        #print(sss)
    except:
        print("Error - INSERT INTO text_table (header, article, art_date) VALUES ('"+head+"','"+art+"', '"+a[1]+"')")
    
    con.commit()
# Out:
# Error - INSERT INTO text_table (header, article, art_date) VALUES ('Ubisoft анонсировала новый Assassin’s Creed','Компания Ubisoft показала тизер новой игры серии Assassin's Creed. Ролик опубликован на официальной странице игры в Twitter. Незадолго до анонса в сети появилось изображение брелока со шлемом воина и подписью Assassin's Creed Odyssey. По информации Kotaku, действие игры будет разворачиваться в Древней Греции, кроме того, будет возможность выбрать между двумя игровыми персонажами. Ожидается, что игра выйдет до 31 марта 2019 года, релиз может состояться осенью 2018-го. Ubisoft подробно расскажет об игре на собственной пресс-конференции на E3. Она пройдет 11 июня, начало в 23:00 по московскому времени.
# ', '2018/06/01')
# Error - INSERT INTO text_table (header, article, art_date) VALUES ('На ВДНХ показали модные платья','В Москве в павильоне выставочного комплекса ВДНХ прошло дефиле коллекции модного дома Chanel «Париж — Гамбург» Métiers d’art 2017/18, сообщает корреспондент «Ленты.ру». Коллекция, впервые показанная в декабре 2017 года в новом гамбургском концертном зале — Эльбской филармонии. Декорации, отсылавшие к теме грузового порта Гамбурга, были воссозданы на ВДНХ в павильоне №69 с учетом его архитектурных особенностей. В основе идеи коллекции — форма моряков торгового флота, переработанная креативным директором дома Карлом Лагерфельдом. Среди гостей показа были посланница дома Каролин де Мегрэ, актрисы Джоанна Прайсс, Равшана Куркова, Марин Вакт, Ирина Старшенбаум, Ксения и Полина Кутеповы, корейская модель Су Джу Пак, балерина Анастасия Шевцова. После показа гостей ждало афтерпати с участием DJ Су Джу Пака, певицы Mabel и Гриши Урганта. Во время Недели высокой моды в Париже в январе 2018 года компания Chanel представила ювелирную коллекцию haute joaillerie под названием L'Esprit du Lion («Львиный дух»). В коллекцию вошли кольца, серьги, колье, сотуары, браслеты и вечерние часы из белого и желтого золота с бриллиантами (бесцветными и желтыми), желтыми бериллами, сапфирами разных оттенков и топазами. Всего в линии 53 предмета. Создатели украшений вдохновлялись фигурами львов из дерева, мрамора и бронзы из парижской квартиры Габриэль Шанель на рю Камбон, 31.
# ', '2018/06/01')
# Error - INSERT INTO text_table (header, article, art_date) VALUES ('Падение яркого метеорита в Китае сняли на видео','Китаец снял на видео метеорит, упавший в провинции Юнань. Запись с камеры его мобильного в субботу, 2 июня, была опубликована в Twitter-аккаунте People's Daily, China. На них виден момент, как огненный шар пролетел над городом Джингхонг и небо осветила яркая вспышка. «Это невероятный момент», — говорится в подписи к видео. При этом не уточняется, сгорело ли небесное тело в атмосфере или ему удалось достичь поверхности Земли.
# ', '2018/06/02')
# CPU times: user 154 ms, sys: 76.4 ms, total: 230 ms
# Wall time: 58.2 s

# %%
len(text_news)
# Out:
# 224

# %% [markdown]
# Теперь попробуем прочитать записанные данные. С оператором <a href="https://ru.wikipedia.org/wiki/Select_(SQL)">SELECT</a> мы уже знакомы. <i>LIMIT 0, 10</i> говорит СУБД, что вернуть надо 10 записей начиная с 0-й. При следующем запросе можно попросить вернуть следующую порцию записей (например, <i>LIMIT 0, 10</i> вернет 10 записей начиная с 10-й).

# %%
cur.execute("SELECT * FROM text_table LIMIT 0, 20")

# %% [markdown]
# Теперь необходимо получить данные с сервера. <a href="https://dev.mysql.com/doc/connector-python/en/connector-python-api-mysqlcursor-fetchall.html">fetchall</a> получает все результаты запроса. В качестве альтернативы можно использовать получение записей по одной - <a href="https://dev.mysql.com/doc/connector-python/en/connector-python-api-cext-fetch-row.html">fetch_row</a>.

# %%
data=cur.fetchall()

# %% [markdown]
# Посмотрим что у нас получилось в результате запроса. Да, в самом деле первые 10 добавленных статей.<br>
# Ура! Мы умеем сохранять данные в СУБД и получать их обратно.

# %%
data
# Out:
# [{'id_text': 1,
#   'header': '«Королева дерьмовых роботов» перенесла операцию на мозге',
#   'article': 'Шведская YouTube-знаменитость Симона Герц (Simone Giertz), прославившаяся необычными изобретениями, перенесла операцию. Об этом рассказали ее представители в Twitter. Еще в конце апреля девушка сообщила подписчикам о недуге. Оказалось, что у нее в мозге обнаружили доброкачественную опухоль размером с мяч для гольфа. Блогер даже дала ей имя, назвав новообразование Брайаном.  Герц сильно переживала перед хирургическим вмешательством. В одном из предоперационных видео она говорила, что очень напугана. Однако врачи быстро удалили опухоль и спасли девушке жизнь. «Симона вышла из хирургии, и ее врачи очень довольны тем, как все прошло. Она проспала достаточно долго, чтобы сделать неуместную шутку, так что все хорошо», — говорится на ее странице в Twitter.  27-летняя изобретательница из Стокгольма прославилась несколько лет назад, показывая подписчикам свои бесполезные изобретения. Например, Герц демонстрировала самодельный будильник, к которому приделана резиновая рука, избивающая спящего человека. Кроме того, девушка создавала автоматизированную машину для наливания молока в тарелку с хлопьями. Сама Герц называет себя «королевой дерьмовых роботов», на ее канал подписаны более миллиона пользователей.\n',
#   'art_date': '2018/06/01'},
#  {'id_text':
\n',
#   'art_date': '2018/06/01'},
#  {'id_text': 19,
#   'header': 'В белорусской школе первоклашку на последнем звонке заменил беспилотник',
#   'article': 'В белорусском городе Барановичи в одной из школ на последнем звонке первоклашку заменили беспилотником. Об этом сообщает Intex-press. Во время торжественной линейки руководство лицея №1 решило изменить традицию, по которой выпускник несет на плече первоклассницу. Перед вчерашними школьниками директор учебного заведения запустил в небо квадрокоптер с привязанным колокольчиком. В 2014 году в школе имени Томаса Мора в бельгийском Мехелене решили бороться со списыванием во время контрольных и самостоятельных работ с помощью квадрокоптера. Беспилотник  во время занятия летал над партами и снимал происходящее. Картинка передавалась на синхронизированный с аппаратом планшет. Возымел ли эксперимент успех, не уточняется.\n',
#   'art_date': '2018/06/01'},
#  {'id_text': 20,
#   'header': 'Уткин обозвал Черчесова медной статуей',
#   'article': 'Футбольный комментатор Василий Уткин прокомментировал поражение сборной России в товарищеском матче с Австрией. Его слова приводит «Спорт FM». «Невозможно понять логику непрофессионала. Сборную уже давно тренирует медная статуя Черчесова. Надеяться можно только на счастливый случай. Не знаю, что еще сказать. Я хотел бы постараться поменьше говорить о сборной», — заявил Уткин. Журналист раскритиковал главного тренера сборной России Станислава Черчесова. «Мы убедились, что никакого стратегического видения тренерского штаба не было. Вся надежда на вдохновение футболистов. А больше не на что. Сборная зря жила 10 лет, если мы в [Юрии] Жиркове снова видим полузащитника. [Антона] Миранчука вообще нет на поле», — добавил он. 30 мая сборная России проиграла в товарищеском матче национальной команде Австрии со счетом 0:1. Единственный мяч на 28-й минуте встречи забил полузащитник австрийцев Алессандро Шопф. Чемпионат мира стартует 14 июня и продлится по 15 июля. Сборная России сыграет с командами Уругвая, Египта и Саудовской Аравии.\n',
#   'art_date': '2018/06/01'}]

# %% [markdown]
# Добавим новости в словарь пакетами.

# %%
# %%time
data=[]
for a in text_news[:1000]:
    head = a[0].replace("'", "\\'")
    art = a[2].replace("'", "\\'")
    data.append("('{}','{}','{}')".format(a[0].replace("'", "\\'"), a[2].replace("'", "\\'"), a[1]))

for i in range(3):
    req="INSERT INTO text_table (header, article, art_date) VALUES " + ",".join(data[i*100:(i+1)*100])
    cur.execute(req)
con.commit()
# Out:
# CPU times: user 8.7 ms, sys: 14 µs, total: 8.71 ms
# Wall time: 183 ms

# %% [markdown]
# Создадим словарь токенов и их частот.

# %%
news_dict = []
for art in text_news:
    words = re.findall("([А-ЯЁа-яё]+(-[А-ЯЁа-яё]+)*)", art[2])
    words = list([w[0].lower() for w in words])
    news_dict.extend(words)
    
news_dict = list(set(news_dict))

# %%
len(news_dict)
# Out:
# 12233

# %%
# tqdm красиво умеет показывать прогресс вычислений.
from tqdm.auto import tqdm

# %%
cur.execute("""CREATE TABLE news_freq (
  id_token INT NOT NULL AUTO_INCREMENT,
  token VARCHAR(256) NULL,
  freq INT NULL,
  PRIMARY KEY (id_token),
  UNIQUE INDEX id_token_UNIQUE (id_token ASC) VISIBLE);
""")

# %%
data = []
cntr = 0
cntr2 = 0
for a in tqdm(news_dict):
    data.append(f"('{a}', 0)")
    cntr += 1
    if cntr == 100:
        req="INSERT INTO news_freq (token, freq) VALUES " + ",".join(data)
        cur.execute(req)
        cntr = 0
        data = []
        cntr2 += 1
        if cntr2 == 10:
            con.commit()
            cntr2 = 0
            
if len(data) != 0:
    req="INSERT INTO news_freq (token, freq) VALUES " + ",".join(data)
    cur.execute(req)
con.commit()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12233.0), HTML(value='')))

# %% [markdown]
# Посчитаем частоты слов в документах или всего в корпусе.

# %%
from collections import Counter

# %%
news_dict = []
for art in text_news:
    words = re.findall("[А-ЯЁа-яё]+", art[2])
    words = list([w.lower() for w in words])
    news_dict.extend(words)
    
#news_dict = list(set(news_dict))

freq_news = Counter(news_dict)

# %%
freq_news
# Out:
# Counter({'шведская': 1,
#          'знаменитость': 1,
#          'симона': 2,
#          'герц': 4,
#          'прославившаяся': 1,
#          'необычными': 1,
#          'изобретениями': 1,
#          'перенесла': 7,
#          'операцию': 6,
#          'об': 191,
#          'этом': 187,
#          'рассказали': 7,
#          'ее': 64,
#          'представители': 10,
#          'в': 1770,
#          'еще': 39,
#          'конце': 3,
#          'апреля': 13,
#          'девушка': 6,
#          'сообщила': 10,
#          'подписчикам': 2,
#          'о': 164,
#          'недуге': 1,
#          'оказалось': 3,
#          'что': 500,
#          'у': 72,
#          'нее': 5,
#          'мозге': 1,
#          'обнаружили': 9,
#          'доброкачественную': 1,
#          'опухоль': 3,
#          'размером': 1,
#          'с': 448,
#          'мяч': 2,
#          'для': 108,
#          'гольфа': 1,
#          'блогер': 4,
#          'даже': 14,
#          'дала': 1,
#          'ей': 13,
#          'имя': 10,
#          'назвав': 1,
#          'новообразование': 1,
#          'брайаном': 1,
#          'сильно': 4,
#          'переживала': 1,
#          'перед': 13,
#          'хирургическим': 1,
#          'вмешательством': 1,
#          'одном': 6,
#          'из': 244,
#          'предоперационных': 1,
#          'видео': 25,
#          'она': 48,
#          'говорила': 1,
#          'очень': 21,
#          'напугана': 1,
#          'однако': 58,
#          'врачи': 4,
#          'быстро': 3,
#          'удалили': 1,
#          'и': 850,
#          'спасли': 2,
#          'девушке': 1,
#          'жизнь': 10,
#          'вышла': 5,
#          'хирургии': 3,
#          'довольны': 1,
#          'тем': 13,
#          'как': 127,
#          'все': 71,
#          'прошло': 5,
#          'проспала': 1,
#          'достаточно': 4,
#          'долго': 3,
#          'чтобы': 41,
#          'сделать': 7,
#          'неуместную': 1,
#          'шутку': 2,
#          'так': 49,
#          'хорошо': 3,
#          'говорится': 28,
#          'на': 811,
#          'странице': 7,
#          'летняя': 13,
#          'изобретательница': 1,
#          'стокгольма': 1,
#          'прославилась': 1,
#          'несколько': 33,
#          'лет': 55,
#          'назад': 6,
#          'показывая': 1,
#          'свои': 16,
#          'бесполезные': 1,
#          'изобретения': 2,
#          'например': 5,
#          'демонстрировала': 1,
#          'самодельный': 1,
#          'будильник': 1,
#          'к': 140,
#          'которому': 4,
#          'приделана': 1,
#          'резиновая': 1,
#          'рука': 1,
#          'избивающая': 1,
#          'спящего': 1,
#          'человека': 17,
#          'кроме': 27,
#          'того': 42,
#          'создавала': 2,
#          'автоматизированную': 1,
#          'машину': 3,
#          'наливания': 1,
#          'молока': 1,
#          'тарелку': 1,
#          'хлопьями': 1,
#          'сама': 3,
#          'называет': 4,
#          'себя': 25,
#          'королевой': 1,
#          'дерьмовых': 1,
#          'роботов': 1,
#          'канал': 5,
#          'подписаны': 2,
#          'более': 59,
#          'миллиона': 24,
#          'пользователей': 13,
#          'перспективный': 1,
#          'российский': 11,
#          'многофункциональный': 1,
#          'истребитель': 1,
#          'пятого': 2,
#          'поколения': 1,
#          'су': 15,
#          'не': 314,
#          'имеет': 10,
#          'мировых': 1,
#          'аналогов': 1,
#          'нем': 11,
#          'могут': 27,
#          'судить': 2,
#          'дилетанты': 1,
#          'сми': 12,
#          'поскольку': 14,
#          'его': 173,
#          'ноу': 2,
#          'хау': 2,
#          'являются': 9,
#          'тайной': 3,
#          'которых': 12,
#          'знают': 3,
#          'лишь': 16,
#          'профессионалы': 2,
#          'испытатели': 2,
#          'военное': 6,
#          'руководство': 11,
#          'страны': 36,
#          'такую': 1,
#          'точку': 4,
#          'зрения': 5,
#          'риа': 23,
#          'новости': 25,
#          'высказал': 2,
#          'летчик': 10,
#          'испытатель': 4,
#          'магомед': 1,
#          'толбоев': 2,
#          'ни': 8,
#          'самолете': 3,
#          'никогда': 7,
#          'удавалось': 2,
#          'добиться': 2,
#          'крейсерских': 1,
#          'сверхзвуковых': 2,
#          'скоростях': 1,
#          'километров': 9,
#          'час': 4,
#          'можно': 28,
#          'было': 43,
#          'летать': 1,
#          'бесфорсажном': 1,
#          'режиме': 2,
#          'форсажный': 1,
#          'режим': 2,
#          'сопряжен': 1,
#          'огромной': 2,
#          'тратой': 1,
#          'топлива': 10,
#          'а': 123,
#          'может': 41,
#          'развивать': 3,
#          'крейсерскую': 1,
#          'скорость': 2,
#          'номинале': 1,
#          'этого': 40,
#          'мире': 5,
#          'добился': 1,
#          'никто': 4,
#          'франция': 3,
#          'англия': 1,
#          'говорит': 7,
#          'будущим': 2,
#          'российской': 12,
#          'боевой': 4,
#          'авиации': 5,
#          'реализованы': 2,
#          'самые': 7,
#          'передовые': 1,
#          'технологии': 4,
#          'то': 55,
#          'демонстрируется': 1,
#          'широкой': 1,
#          'общественности': 1,
#          'это': 124,
#          'поверхность': 1,
#          'остальное': 1,
#          'знаем': 2,
#          'только': 41,
#          'мы': 58,
#          'эти': 15,
#          'дилетантам': 1,
#          'перспективах': 1,
#          'этой': 14,
#          'машины': 6,
#          'сказал': 32,
#          'он': 183,
#          'таким': 16,
#          'образом': 12,
#          'летний': 18,
#          'отреагировал': 2,
#          'публикацию': 3,
#          'американского': 10,
#          'журнала': 1,
#          'котором': 15,
#          'полагают': 2,
#          'будет': 68,
#          'особо': 3,
#          'яркого': 1,
#          'будущего': 2,
#          'издание': 23,
#          'отмечает': 14,
#          'основан': 3,
#          'системах': 1,
#          'разработанных': 1,
#          'основное': 2,
#          'улучшение': 1,
#          'новом': 7,
#          'коснулось': 1,
#          'планера': 1,
#          'который': 49,
#          'предлагает': 5,
#          'некоторую': 1,
#          'степень': 3,
#          'скрытности': 1,
#          'также': 116,
#          'москва': 6,
#          'продолжит': 4,
#          'модернизацию': 1,
#          'см': 1,
#          'использованием': 2,
#          'авионики': 1,
#          'от': 107,
#          'до': 69,
#          'толбоева': 1,
#          'анатолий': 3,
#          'кнышов': 2,
#          'говоря': 4,
#          'эксперт': 4,
#          'заявил': 58,
#          'зарубежный': 1,
#          'мир': 1,
#          'интересуется': 2,
#          'характеристиками': 1,
#          'характеристики': 1,
#          'превзошел': 1,
#          'впереди': 2,
#          'планеты': 1,
#          'всей': 5,
#          'санкт': 6,
#          'петербургский': 4,
#          'клуб': 11,
#          'континентальной': 2,
#          'хоккейной': 3,
#          'лиги': 16,
#          'кхл': 3,
#          'ска': 4,
#          'объявил': 14,
#          'уходе': 5,
#          'главного': 8,
#          'тренера': 8,
#          'команды': 9,
#          'олега': 6,
#          'знарка': 3,
#          'со': 79,
#          'своего': 14,
#          'поста': 2,
#          'сообщает': 80,
#          'пресс': 27,
#          'служба': 11,
#          'поблагодарило': 1,
#          'за': 217,
#          'проделанную': 1,
#          'работу': 12,
#          'пожелало': 1,
#          'успехов': 2,
#          'дальнейшей': 1,
#          'карьере': 2,
#          'вместе': 13,
#          'знарком': 1,
#          'команду': 6,
#          'покинули': 4,
#          'тренеры': 1,
#          'харийс': 1,
#          'витолиньш': 1,
#          'владимир': 12,
#          'федосов': 1,
#          'знарок': 3,
#          'возглавил': 1,
#          'июне': 4,
#          'го': 21,
#          'под': 52,
#          'руководством': 6,
#          'выиграл': 3,
#          'кубок': 3,
#          'гагарина': 1,
#          'стал': 21,
#          'чемпионом': 6,
#          'россии': 134,
#          'обладателем': 4,
#          'кубка': 6,
#          'континента': 1,
#          'покинул': 8,
#          'пост': 11,
#          'сборной': 16,
#          'занимал': 3,
#          'года': 129,
#          'место': 24,
#          'был': 88,
#          'назначен': 2,
#          'илья': 1,
#          'воробьев': 11,
#          'дважды': 7,
#          'приводил': 1,
#          'сборную': 4,
#          'первому': 4,
#          'месту': 3,
#          'чемпионатах': 2,
#          'мира': 23,
#          'золоту': 1,
#          'хоккейного': 1,
#          'турнира': 6,
#          'олимпиады': 2,
#          'пхенчхане': 1,
#          'следственный': 1,
#          'комитет': 2,
#          'по': 385,
#          'москве': 12,
#          'начал': 7,
#          'проверку': 3,
#          'факту': 3,
#          'возможного': 1,
#          'применения': 2,
#          'сотрудниками': 5,
#          'полиции': 11,
#          'физической': 1,
#          'силы': 9,
#          'отношении': 20,
#          'молодого': 2,
#          'аутизмом': 1,
#          'сайте': 23,
#          'ведомства': 9,
#          'настоящее': 15,
#          'время': 86,
#          'проводится': 4,
#          'комплекс': 1,
#          'необходимых': 2,
#          'проверочных': 1,
#          'мероприятий': 1,
#          'направленный': 1,
#          'установление': 1,
#          'всех': 16,
#          'обстоятельств': 1,
#          'произошедшего': 3,
#          'результатам': 1,
#          'проверки': 2,
#          'принято': 10,
#          'процессуальное': 1,
#          'решение': 28,
#          'утверждает': 5,
#          'ск': 5,
#          'следователи': 4,
#          'заинтересовались': 2,
#          'новостью': 1,
#          'том': 41,
#          'полицейские': 7,
#          'задержали': 8,
#          'шумного': 1,
#          'применяли': 1,
#          'нему': 7,
#          'спецсредства': 1,
#          'два': 35,
#          'часа': 2,
#          'держали': 1,
#          'отделении': 2,
#          'вызвали': 1,
#          'врачей': 1,
#          'которые': 44,
#          'отвезли': 1,
#          'психиатрическую': 1,
#          'больницу': 3,
#          'позднее': 9,
#          'мать': 7,
#          'татьяна': 2,
#          'иванова': 2,
#          'написала': 5,
#          'сын': 5,
#          'павел': 4,
#          'васильев': 1,
#          'инвалид': 1,
#          'детства': 2,
#          'аутист': 1,
#          'применялось': 1,
#          'насилие': 2,
#          'мне': 16,
#          'потом': 6,
#          'рассказал': 40,
#          'раз': 18,
#          'душили': 2,
#          'завязывали': 1,
#          'ему': 30,
#          'рот': 1,
#          'голову': 3,
#          'футболкой': 1,
#          'очевидно': 2,
#          'качестве': 11,
#          'успокоительного': 1,
#          'добавила': 2,
#          'пользователи': 17,
#          'сети': 7,
#          'начали': 15,
#          'сбор': 1,
#          'подписей': 1,
#          'доступ': 6,
#          'близких': 2,
#          'родственников': 2,
#          'задержанным': 2,
#          'людям': 2,
#          'ментальными': 1,
#          'нарушениями': 1,
#          'жителей': 7,
#          'киева': 3,
#          'перекрыли': 1,
#          'проспект': 2,
#          'григоренко': 1,
#          'четверг': 2,
#          'вечером': 2,
#          'после': 81,
#          'дтп': 6,
#          'пострадал': 1,
#          'ребенок': 8,
#          'интерфакс': 6,
#          'украина': 15,
#          'утверждению': 8,
#          'очевидцев': 2,
#          'пересекавшего': 1,
#          'пешеходный': 1,
#          'переход': 2,
#          'мальчика': 6,
#          'велосипеде': 1,
#          'сбил': 3,
#          'автомобиль': 8,
#          'кортежа': 1,
#          'президента': 29,
#          'петра': 2,
#          'порошенко': 4,
#          'администрации': 5,
#          'главы': 9,
#          'государства': 11,
#          'эту': 9,
#          'информацию': 9,
#          'опровергли': 2,
#          'национальной': 8,
#          'выпустила': 2,
#          'заявление': 2,
#          'признала': 1,
#          'ответственность': 3,
#          'случившееся': 1,
#          'уточнив': 3,
#          'принадлежит': 4,
#          'правоохранительным': 1,
#          'органам': 1,
#          'момент': 15,
#          'следовал': 1,
#          'спецзадание': 1,
#          'находившиеся': 2,
#          'машине': 2,
#          'прошли': 5,
#          'тест': 1,
#          'алкоголь': 1,
#          'присутствии': 1,
#          'понятых': 1,
#          'прибор': 1,
#          'выявил': 1,
#          'следов': 2,
#          'этанола': 1,
#          'водитель': 1,
#          'направлен': 2,
#          'наркологическую': 1,
#          'экспертизу': 1,
#          'марта': 8,
#          'кортеж': 3,
#          'пожилого': 1,
#          'мужчину': 7,
#          'пытался': 4,
#          'перебежать': 1,
#          'дорогу': 3,
#          'пострадавший': 3,
#          'пришел': 2,
#          'сознание': 1,
#          'признался': 8,
#          'нарушении': 1,
#          'правил': 2,
#          'дорожного': 2,
#          'движения': 4,
#          'российская': 10,
#          'прыгунья': 1,
#          'высоту': 3,
#          'мария': 2,
#          'ласицкене': 3,
#          'одержала': 1,
#          'ю': 1,
#          'победу': 7,
#          'подряд': 5,
#          'выиграв': 2,
#          'этап': 2,
#          'бриллиантовой': 2,
#          'риме': 1,
#          'корреспондент': 10,
#          'ленты': 14,
#          'ру': 22,
#          'взяла': 1,
#          'метра': 8,
#          'обеспечила': 1,
#          'себе': 6,
#          'первое': 5,
#          'спортсменка': 3,
#          'показала': 2,
#          'лучший': 3,
#          'результат': 3,
#          'сезона': 6,
#          'второе': 2,
#          'заняла': 4,
#          'болгарская': 1,
#          'мирела': 1,
#          'демирева': 1,
#          'третьем': 7,
#          'месте': 9,
#          'расположилась': 1,
#          'итальянка': 1,
#          'елена': 4,
#          'валлортигара': 1,
#          'победная': 1,
#          'серия': 2,
#          'россиянки': 1,
#          'началась': 1,
#          'июле': 4,
#          'всероссийской': 1,
#          'летней': 3,
#          'универсиаде': 1,
#          'выиграла': 2,
#          'чемпионат': 8,
#          'помещении': 2,
#          'этапы': 1,
#          'бриллиантовая': 1,
#          'лига': 1,
#          'ежегодная': 2,
#          'коммерческих': 2,
#          'соревнований': 2,
#          'легкой': 1,
#          'атлетике': 1,
#          'организованная': 1,
#          'международной': 5,
#          'ассоциацией': 1,
#          'легкоатлетических': 1,
#          'федераций': 1,
#          'приложении': 3,
#          'устройств': 1,
#          'нашли': 5,
#          'необычный': 1,
#          'баг': 1,
#          'позволяющий': 1,
#          'прочитать': 1,
#          'последнее': 4,
#          'сообщение': 6,
#          'телефоне': 1,
#          'пользователь': 5,
#          'имиджборда': 1,
#          'ником': 4,
#          'владелец': 2,
#          'смартфона': 2,
#          'каждый': 8,
#          'при': 62,
#          'вводе': 2,
#          'поисковую': 1,
#          'строку': 1,
#          'запроса': 1,
#          'результатах': 1,
#          'видит': 5,
#          'последние': 7,
#          'текстовые': 1,
#          'сообщения': 3,
#          'смартфоне': 2,
#          'похоже': 1,
#          'самый': 3,
#          'странный': 1,
#          'сбой': 3,
#          'которым': 8,
#          'я': 64,
#          'когда': 27,
#          'либо': 10,
#          'сталкивался': 1,
#          'просто': 8,
#          'случайное': 1,
#          'совпадение': 1,
#          'или': 47,
#          'происходит': 3,
#          'другое': 3,
#          'задался': 1,
#          'вопросом': 2,
#          'другие': 19,
#          'смартфонов': 2,
#          'управлением': 1,
#          'имеют': 1,
#          'такие': 12,
#          'же': 41,
#          'симптомы': 3,
#          'они': 63,
#          'столкнулись': 2,
#          'подобной': 1,
#          'проблемой': 1,
#          'пытались': 4,
#          'произвести': 1,
#          'поиск': 2,
#          'фразам': 1,
#          'судя': 1,
#          'всему': 5,
#          'запросы': 1,
#          'каким': 3,
#          'запускают': 1,
#          'функцию': 2,
#          'показа': 4,
#          'текстовых': 1,
#          'сообщений': 3,
#          'которая': 27,
#          'доступна': 2,
#          'неясно': 1,
#          'перечисленные': 1,
#          'фразы': 1,
#          'наборы': 1,
#          'символов': 1,
#          'связаны': 2,
#          'запуском': 2,
#          'юзеры': 2,
#          'обратили': 4,
#          'внимание': 15,
#          'браузере': 1,
#          'выдает': 1,
#          'корректные': 1,
#          'результаты': 5,
#          'ранее': 44,
#          'сервисе': 1,
#          'оскорбление': 2,
#          'предназначенное': 1,
#          'плосковерам': 1,
#          'считают': 11,
#          'землю': 3,
#          'плоской': 1,
#          'переводе': 1,
#          'английского': 4,
#          'языка': 1,
#          'французский': 4,
#          'фраза': 2,
#          'плосковер': 1,
#          'превращалась': 1,
#          'фразу': 3,
#          'сумасшедший': 1,
#          'встрече': 11,
#          'лидера': 4,
#          'кндр': 15,
#          'ким': 32,
#          'чен': 19,
#          'ына': 12,
#          'министром': 3,
#          'иностранных': 9,
#          'дел': 9,
#          'сергеем': 2,
#          'лавровым': 2,
#          'была': 29,
#          'достигнута': 2,
#          'договоренность': 3,
#          'высшем': 4,
#          'уровне': 12,
#          'сообщении': 9,
#          'государственного': 4,
#          'информагентства': 1,
#          'северной': 6,
#          'кореи': 11,
#          'цтак': 1,
#          'передает': 18,
#          'целях': 5,
#          'развития': 9,
#          'стратегических': 2,
#          'традиционных': 1,
#          'корейско': 1,
#          'российских': 19,
#          'отношений': 2,
#          'соответствии': 5,
#          'интересами': 1,
#          'обеих': 1,
#          'сторон': 2,
#          'требованием': 6,
#          'новой': 8,
#          'эпохи': 1,
#          'нынешнем': 3,
#          'году': 65,
#          'отмечается': 15,
#          'годовщина': 1,
#          'установления': 1,
#          'дипломатических': 1,
#          'между': 20,
#          'двумя': 6,
#          'странами': 4,
#          'активизировать': 1,
#          'контакты': 3,
#          'высоком': 1,
#          'обмен': 4,
#          'сотрудничество': 2,
#          'разных': 5,
#          'сферах': 1,
#          'частности': 11,
#          'провести': 8,
#          'встречу': 6,
#          'высших': 1,
#          'руководителей': 3,
#          'заявили': 12,
#          'пхеньяне': 1,
#          'мая': 110,
#          'сообщалось': 27,
#          'лавров': 5,
#          'пригласил': 2,
#          'россию': 13,
#          'тот': 13,
#          'ответ': 18,
#          'поблагодарил': 5,
#          'приглашение': 2,
#          'попросил': 4,
#          'передать': 2,
#          'привет': 2,
#          'владимиру': 4,
#          'путину': 5,
#          'российскому': 3,
#          'народу': 2,
#          'северокорейский': 2,
#          'лидер': 12,
#          'поинтересовался': 2,
#          'здоровьем': 2,
#          'путина': 11,
#          'июня': 97,
#          'сингапуре': 9,
#          'запланирован': 5,
#          'саммит': 5,
#          'президентом': 10,
#          'сша': 89,
#          'дональдом': 2,
#          'трампом': 3,
#          'темой': 6,
#          'встречи': 16,
#          'должна': 16,
#          'стать': 16,
#          'денуклеаризация': 6,
#          'корейского': 6,
#          'полуострова': 8,
#          'стороны': 22,
#          'поочередно': 1,
#          'заявляют': 2,
#          'отмене': 2,
#          'подготовки': 6,
#          'возобновлении': 2,
#          'переговорного': 1,
#          'процесса': 2,
#          'стало': 19,
#          'известно': 20,
#          'лидеров': 7,
#          'двух': 20,
#          'корей': 1,
#          'уже': 23,
#          'вторая': 3,
#          'встреча': 6,
#          'корейских': 1,
#          'месяц': 7,
#          'первые': 2,
#          'переговоры': 10,
#          'состоялись': 2,
#          'туристка': 1,
#          'великобритании': 6,
#          'поднимавшаяся': 1,
#          'гору': 1,
#          'районе': 8,
#          'новозеландского': 1,
#          'города': 12,
#          'таупо': 1,
#          'упала': 4,
#          'высоты': 1,
#          'метров': 6,
#          'осталась': 4,
#          'жива': 3,
#          'британка': 2,
#          'живущая': 1,
#          'работающая': 1,
#          'зеландии': 2,
#          'отправилась': 2,
#          'горы': 2,
#          'девушкой': 1,
#          'австрии': 5,
#          'во': 71,
#          'восхождения': 1,
#          'поскользнулась': 1,
#          'льду': 1,
#          'расщелину': 2,
#          'пути': 3,
#          'женщина': 14,
#          'ударялась': 1,
#          'камни': 1,
#          'лед': 1,
#          'стукнулась': 1,
#          'головой': 2,
#          'но': 76,
#          'отделавшись': 1,
#          'ушибами': 1,
#          'порезами': 1,
#          'ссадинами': 1,
#          'спутница': 1,
#          'видела': 1,
#          'куда': 6,
#          'поначалу': 1,
#          'опасалась': 1,
#          'та': 2,
#          'погибла': 2,
#          'итоге': 11,
#          'им': 12,
#          'удалось': 8,
#          'докричаться': 1,
#          'друг': 4,
#          'друга': 3,
#          'через': 23,
#          'десять': 3,
#          'минут': 5,
#          'падения': 2,
#          'австрийка': 1,
#          'связалась': 1,
#          'экстренными': 1,
#          'службами': 1,
#          'происшествии': 1,
#          'помощь': 8,
#          'пострадавшей': 1,
#          'выслали': 1,
#          'вертолет': 3,
#          'высадил': 1,
#          'медиков': 2,
#          'недалеко': 4,
#          'ущелья': 1,
#          'где': 37,
#          'находилась': 1,
#          'затем': 12,
#          'доставил': 1,
#          'добровольцев': 4,
#          'спасателей': 1,
#          'горе': 1,
#          'которой': 18,
#          'прежнему': 2,
#          'сидела': 2,
#          'поднялись': 3,
#          'ней': 13,
#          'помогли': 2,
#          'слезть': 1,
#          'спасателям': 1,
#          'отыскать': 1,
#          'гималаях': 1,
#          'упавшего': 1,
#          'ледниковую': 1,
#          'альпиниста': 1,
#          'джона': 2,
#          'олла': 1,
#          'благодаря': 6,
#          'размещенному': 1,
#          'статусу': 1,
#          'просьбой': 3,
#          'помощи': 5,
#          'раненый': 1,
#          'мужчина': 18,
#          'просидел': 1,
#          'ущелье': 1,
#          'часов': 5,
#          'госдума': 1,
#          'объявила': 4,
#          'тендер': 1,
#          'проведение': 3,
#          'исследования': 6,
#          'лучших': 3,
#          'зарубежных': 3,
#          'практиках': 1,
#          'борьбе': 4,
#          'бедностью': 1,
#          'снижению': 1,
#          'социально': 3,
#          'экономического': 4,
#          'неравенства': 1,
#          'ссылкой': 22,
#          'портал': 10,
#          'госзакупок': 1,
#          'исследование': 4,
#          'рекомендации': 1,
#          'совершенствованию': 1,
#          'законодательного': 1,
#          'регулирования': 3,
#          'планируется': 12,
#          'потратить': 2,
#          'рублей': 55,
#          'депутаты': 1,
#          'планируют': 3,
#          'взять': 4,
#          'образец': 1,
#          'опыт': 2,
#          'скандинавских': 1,
#          'стран': 23,
#          'континентальных': 1,
#          'евросоюза': 8,
#          'государств': 4,
#          'постсоветского': 1,
#          'пространства': 1,
#          'законотворцы': 1,
#          'рассчитывают': 1,
#          'получить': 7,
#          'подготовленные': 1,
#          'материалы': 3,
#          'теме': 2,
#          'концу': 2,
#          'осени': 1,
#          'поясняется': 1,
#          'актуальность': 3,
#          'данного': 2,
#          'обусловлена': 1,
#          'поставленной': 1,
#          'владимиром': 6,
#          'путиным': 6,
#          'задачей': 3,
#          'шесть': 9,
#          'вдвое': 4,
#          'снизить': 3,
#          'бедность': 1,
#          'вице': 11,
#          'премьер': 11,
#          'социальной': 2,
#          'политике': 3,
#          'голикова': 1,
#          'заявила': 16,
#          'самой': 6,
#          'трудновыполнимой': 1,
#          'нового': 6,
#          'майского': 1,
#          'указа': 2,
#          'владимира': 6,
#          'снижение': 2,
#          'уровня': 8,
#          'бедности': 2,
#          'стране': 13,
#          'раза': 6,
#          'президент': 50,
#          'подписал': 8,
#          'указ': 2,
#          'национальных': 1,
#          'задачах': 1,
#          'документ': 3,
#          'охватывает': 2,
#          'направлений': 2,
#          'деятельности': 9,
#          'правительства': 12,
#          'основные': 3,
#          'задачи': 2,
#          'каждому': 2,
#          'них': 21,
#          'помимо': 9,
#          'снижения': 2,
#          'указе': 1,
#          'ставятся': 1,
#          'устойчивого': 1,
#          'демографического': 1,
#          'роста': 4,
#          'повышения': 1,
#          'продолжительности': 1,
#          ...})

# %%
data = []
cntr = 0
cntr2 = 0
for t, f in tqdm(freq_news.items()):
    data.append(f"('{t}', {f})")
    cntr += 1
    if cntr == 100:
        req="INSERT INTO news_freq (token, freq) VALUES " + ",".join(data)
        cur.execute(req)
        cntr = 0
        data = []
        cntr2 += 1
        if cntr2 == 10:
            con.commit()
            cntr2 = 0
            
if len(data) != 0:
    req="INSERT INTO news_freq (token, freq) VALUES " + ",".join(data)
    cur.execute(req)
con.commit()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12227.0), HTML(value='')))

# %%
# Удалим слова, которые обавили вначале с нулевой частотой.
cur.execute("DELETE FROM news_freq WHERE freq=0")

# %%
cur.execute("SELECT count(*) as cnt, avg(freq) as avg_freq FROM texts4experiments.news_freq")
res = cur.fetchall()
print(f"Количество записей:{res[0]['cnt']}, средняя частота токена {res[0]['avg_freq']}")
# Out:
# Количество записей:12227, средняя частота токена 2.9851

# %% [markdown]
# Посмотрим как выбираются статьи из базы.

# %%
cur.execute("SELECT id_text, article FROM text_table")
news_from_db = cur.fetchall()

# %%
news_from_db[:3]
# Out:
# [{'id_text': 1,
#   'article': 'Шведская YouTube-знаменитость Симона Герц (Simone Giertz), прославившаяся необычными изобретениями, перенесла операцию. Об этом рассказали ее представители в Twitter. Еще в конце апреля девушка сообщила подписчикам о недуге. Оказалось, что у нее в мозге обнаружили доброкачественную опухоль размером с мяч для гольфа. Блогер даже дала ей имя, назвав новообразование Брайаном.  Герц сильно переживала перед хирургическим вмешательством. В одном из предоперационных видео она говорила, что очень напугана. Однако врачи быстро удалили опухоль и спасли девушке жизнь. «Симона вышла из хирургии, и ее врачи очень довольны тем, как все прошло. Она проспала достаточно долго, чтобы сделать неуместную шутку, так что все хорошо», — говорится на ее странице в Twitter.  27-летняя изобретательница из Стокгольма прославилась несколько лет назад, показывая подписчикам свои бесполезные изобретения. Например, Герц демонстрировала самодельный будильник, к которому приделана резиновая рука, избивающая спящего человека. Кроме того, девушка создавала автоматизированную машину для наливания молока в тарелку с хлопьями. Сама Герц называет себя «королевой дерьмовых роботов», на ее канал подписаны более миллиона пользователей.\n'},
#  {'id_text': 2,
#   'article': 'Перспективный российский многофункциональный истребитель пятого поколения Су-57 не имеет мировых аналогов и о нем не могут судить «дилетанты из СМИ», поскольку его «ноу-хау являются тайной», о которых знают лишь «профессионалы, испытатели, военное руководство страны». Такую точку зрения РИА Новости высказал летчик-испытатель Магомед Толбоев. «Ни на одном самолете еще никогда не удавалось добиться того, чтобы на крейсерских сверхзвуковых скоростях (1600 километров в час) можно было летать в бесфорсажном режиме. Форсажный режим сопряжен с огромной тратой топлива, а Су-57 может развивать крейсерскую скорость "на номинале". Этого в мире еще не добился никто — ни Франция, ни Англия, ни Rolls-Royce, ни Pratt & Whitney — никто», — говорит Толбоев. Летчик-испытатель называет Су-57 «будущим российской боевой авиации». «В нем реализованы самые передовые технологии и то, что демонстрируется широкой общественности, — это лишь поверхность, остальное знаем только мы — профессионалы, испытатели, военное руководство страны. Эти ноу-хау являются тайной, и не дилетантам из СМИ судить о перспективах этой машины», — сказал он. Таким образом 67-летний летчик-испытатель отреагировал на публикацию американского журнала The National Interest, в котором полагают, что «у Су-57 не будет особо яркого будущего». Издание отмечает, что Су-57 основан на «системах, разработанных для Су-35С», а основное улучшение в новом самолете коснулось планера, который «предлагает некоторую степень скрытности», а также то, что «Москва продолжит модернизацию Су-30СМ и Су-35С с использованием технологии авионики от Су-57». До Толбоева на публикацию The National Interest отреагировал летчик-испытатель Анатолий Кнышов. Говоря о Су-57, эксперт заявил, что «зарубежный мир интересуется его характеристиками, его характеристики не превзошел никто в мире». «Мы впереди планеты всей», — сказал Кнышов.\n'},
#  {'id_text': 3,
#   'article': 'Санкт-петербургский клуб Континентальной хоккейной лиги (КХЛ) СКА объявил об уходе главного тренера команды Олега Знарка со своего поста. Об этом сообщает пресс-служба команды. Руководство СКА поблагодарило Знарка за проделанную работу и пожелало успехов в дальнейшей карьере. Вместе со Знарком команду покинули тренеры Харийс Витолиньш и Владимир Федосов. Знарок возглавил СКА в июне 2016-го. Под руководством тренера петербургский клуб выиграл Кубок Гагарина, стал чемпионом России и обладателем Кубка Континента. Знарок 12 апреля покинул пост главного тренера сборной, который занимал с апреля 2014 года. На его место был назначен Илья Воробьев. Знарок дважды приводил сборную России к первому месту на чемпионатах мира и к золоту хоккейного турнира Олимпиады в Пхенчхане.\n'}]

# %% [markdown]
# Создадим таблицу, которая хранит в каком документе какое слово сколько раз встретилось.

# %%
cur.execute("DROP TABLE IF EXISTS text2token")

# %%
cur.execute("""CREATE TABLE text2token (
  id_tt INT NOT NULL AUTO_INCREMENT,
  token_id VARCHAR(256) NULL,
  text_id INT NULL,
  freq INT NULL,
  PRIMARY KEY (id_tt),
  UNIQUE INDEX id_tt_UNIQUE (id_tt ASC) VISIBLE);
""")

# %%
for news in tqdm(news_from_db):
    words = re.findall("[А-ЯЁа-яё]+", news['article'])
    words = list([w.lower() for w in words])
    wrd_freqs = Counter(words)
    text_id = news['id_text']
    
    for w, f in wrd_freqs.items():
        cur.execute(f"SELECT id_token FROM news_freq WHERE token='{w}'")
        wid = cur.fetchall()
        if len(wid) == 1:
            tid = wid[0]['id_token']
            cur.execute(f"INSERT INTO text2token (token_id,text_id,freq) VALUES ({tid},{text_id},{f})")
            
con.commit()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=443.0), HTML(value='')))
