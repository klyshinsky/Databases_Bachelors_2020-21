# %% [markdown]
# Попробуем решить следующую задачу: нам необходимо выгрузить сайт NPlus1.ru и положить статьи в базу данных. Отдельно должны лежать идентификаторы загруженных текстов, словари начальных форм и токенов, разбиение текста на предложения. Для решения задачи будем использовать базу данных MongoDB.
#
# Импортируем все необходисые библиотеки. Обратите особое внимание на библиотеку для работы с Mongo - <a href="http://api.mongodb.com/python/current/api/index.html">pymongo</a> (еще одно описание <a href="https://pymongo.readthedocs.io/en/stable/">здесь</a>).

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import datetime
from tqdm import tqdm
import pymorphy2

import pymongo
from bson import ObjectId
from lxml import html

delcom=re.compile("<!--.+-->", re.S)

# %% [markdown]
# Чтобы не ставить себе базу данных, можно использовать бесплатное облако <a href ="https://cloud.mongodb.com/">Mongo.Atlas</a>. Для этого необходимо зарегистрироваться, завести пользователя, создать проект, дать пользователю права на проект. Для пользователя получить строку для соединения с базой.
#
# Но в данном случае мы будем пользоваться MongoDB, запущенное на локальном компьютере при помощи Docker.
#
# Для работы с БД используем класс MongoClient, в который передаем строку соединения.

# %%
# Version after 3.6
client = pymongo.MongoClient('localhost', 27017)
#client = pymongo.MongoClient()

# %% [markdown]
# Аналогом реляционных записей являются документы. Аналогом таблиц - коллекции и подколлекции. Сам документ может включать в себя другие документы. Документ записывается в формате JSON, но для Питона можно считать, что это словари.
# При помощи клиента обращаемся к базе `concordance`. Если эта база не существовала, она создастся при первой записи данных. Аналогично всё происходит с коллекциями.<br>

# %%
# Обращение к базе при помощи оператора квадратные скобки.
db = client['concordance']
# Обращение к базе при помощи оператора точка.
#db = client.concordance

# %% [markdown]
# Посмотрим что содержит в себе база.

# %%
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'concordance')

# %%
# Обращение к коллекции внутри базы при помощи оператора точка (но можно и при помощи квадратных скобок).
text_collection = db.nplus1texts
dictionary = db.dictionary
lemmas = db.lemmas
dbsents = db.sentences

# %% [markdown]
# В коллекции `nplus1texts` будем хранить адерса и идентификаторы текстов, в коллекции `dictionary` - словарь токенов, в `lemmas` - словарь лемм, наконец в `sentences` - разделение предложений на слова.

# %% [markdown]
# Для того, чтобы найти документ, необходимо использовать функцию `collection.find()`. Без параметров эта функция выдаст все документы.

# %%
from pprint import pprint

# %%
for t in text_collection.find()[:2]:
    pprint(t)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'),
#  'art_info': {'art_date': '20 Янв. 2020',
#               'art_time': '14:18',
#               'author': 'Александр Войтюк',
#               'difficulty': '2.3'},
#  'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к '
#              'Красной планете этим летом, успешно прошел заключительные '
#              'термовакуумные испытания, имитировавшие\xa0условия марсианской '
#              'среды, в которых предстоит работать роверу,\xa0сообщается на '
#              'сайте ESA.Старт второго этапа российско-европейской программы '
#              '«ЭкзоМарс» намечен на период с 26 июля по 11 августа 2020 года. '
#              'Ракета-носитель «Протон» выведет в космос перелетный модуль, '
#              'который доставит к Марсу десантный модуль, содержащий в себе '
#              'автономную научную станцию «Казачок»\xa0и марсоход «Розалинд '
#              'Франклин». Посадка на поверхность Красной планеты должна '
#              'состояться 19 марта 2021 года, в качестве места работы аппаратов '
#              'выбрана\xa0равнина Оксия в северном полушарии Марса, где есть '
#              'сухие русла. Задачей марсохода будет\xa0поиск соединений и '
#              'веществ, которые могли бы свидетельствовать о возможном '
#              'существовании на планете жизни в прошлом, а также изучение '
#              'геологии Марса. Научная станция займется исследованием\xa0'
#              'состава и свойств поверхности и атмосферы Красной планеты.В '
#              'конце августа 2018 года была завершена сборка марсохода, после '
#              'чего его отправили в цеха компании\xa0Airbus в Тулузе для '
#              'прохождения заключительных термических и вакуумных испытаний, '
#              'имитирующих условия марсианской среды. Аппарат должен '
#              'функционировать\xa0при атмосферном давлении, значение которого '
#              'составляет менее одной сотой от земного, и низких температурах. '
#              'Моделирование показывает, что при температуре окружающего '
#              'воздуха\xa0–120 градусов по Цельсию, температура внутри ровера '
#              'составит –50 градусов по Цельсию.\xa0В конце 2019 года '
#              'испытательная программа была успешно завершена, в настоящее '
#              'время ведется заключительное тестирование всех систем марсохода. '
#              'После его окончания ровер будет перевезен в компанию\xa0Thales '
#              'Alenia Space в Каннах, где будет проведена проверка его '
#              'совместимости с посадочной платформой и десантным модулем.Ранее '
#              'мы рассказывали о трудностях, с которыми пришлось столкнуться '
#              'специалистам при разработке тормозной системы для\xa0'
#              '«ЭкзоМарса-2020».Александр Войтюк\n'
#              '                            \n'
#              '                            \n'
#              '                                                \n'
#              '                        \n'
#              '                                            ',
#  'coord': {'coordinates': [20, 15], 'type': 'Point'},
#  'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания',
#  'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes'}
# {'_id': ObjectId('616fcef5e3381e0ff188026b'),
#  'art_info': {'art_date': '20 Янв. 2020',
#               'art_time': '10:40',
#               'author': 'Олег Макаров',
#               'difficulty': '4.2'},
#  'art_text': '\n'
#              'Физики создали резонатор размером в несколько сотен нанометров, '
#              'способный удерживать свет внутри себя на\xa0время, за\xa0которое '
#              'световая волна совершает более 200 периодов колебаний. На\xa0'
#              'основе него ученые создали устройство, которое увеличивает '
#              'частоту входного света в\xa0два раза, а в будущем такие '
#              'нанорезонаторы могут стать основой для создания оптических '
#              'средств связи, приборов ночного видения и\xa0компактных '
#              'сенсоров. Работа опубликована в\xa0журнале Science. \n'
#              'С\xa0помощью электрооптики можно передавать информацию на\xa0'
#              'расстояние, считывать и\xa0записывать данные. Для контроля света '
#              'его нужно уметь удерживать в\xa0малой области пространства на\xa0'
#              'достаточно долгое время. Но\xa0чем меньше резонатор, тем сложнее '
#              'удержать в\xa0нем волну. До сих пор добиться приемлемого времени '
#              'удержания света на\xa0практике удавалось лишь для резонатора, '
#              'размерами превышающего длину электромагнитной волны. \n'
#              'Попытки ученых создать нанометровый резонатор пока что не были '
#              'очень успешными\xa0— созданные нанорезонаторы обладают малой '
#              'добротностью и\xa0плохо удерживают свет. В\xa02017 году команда '
#              'физиков из\xa0России и\xa0Австралии предсказала новый тип '
#              'диэлектрических резонаторов с\xa0очень высокой добротностью. '
#              'Ее\xa0удалось достичь за\xa0счет реализации режима связанных '
#              'состояний в\xa0континууме. Это явление, открытое в\xa01929 году '
#              'в\xa0квантовой механике, применимо к\xa0разным типам волн '
#              '(электромагнитным, акустическим или волнам на\xa0воде).\n'
#              'Группе физиков из\xa0Нового физтеха Университета ИТМО, '
#              'Австралийского Национального Университета и\xa0Университета Корё '
#              'под руководством Кирилла Кошелева (Kirill Koshelev) удалось '
#              'создать предсказанный два года назад резонатор. Ученые добились '
#              'времени захвата света на\xa0порядок выше, чем в\xa0предыдущих '
#              'работах. \n'
#              '«Из\xa0арсенида галлия были изготовлены цилиндры высотой около '
#              '700\xa0нм с\xa0различными диаметрами, близкими к\xa0900\xa0нм. '
#              'Их\xa0практически не\xa0увидеть невооруженным взглядом. Как '
#              'показал эксперимент, эталонная частица захватила свет на\xa0'
#              'время, превышающее в\xa0200 раз период одного колебания световой '
#              'волны. Обычно для частицы таких размеров этот показатель не\xa0'
#              'превышает 5\xa0— 10\xa0периодов световых колебаний. А\xa0здесь '
#              '200!»,\xa0— говорит Кирилл Кошелев.\n'
#              'Интенсивные импульсы света, взаимодействующие с\xa0диэлектриком, '
#              'могут стать причиной оптически нелинейного отклика среды, в\xa0'
#              'результате чего частота выходной электромагнитной волны может '
#              'быть увеличена в\xa0несколько раз (следовательно, цвет света, '
#              'прошедшего через такую среду изменится в\xa0сторону '
#              'фиолетового). Проблема в\xa0том, что этот процесс довольно слаб '
#              'и\xa0происходит на\xa0расстояниях порядка тысячи длин волн. \n'
#              '\n'
#              '    \n'
#              '        \n'
#              '                        \n'
#              '                \n'
#              '                    \n'
#              '                        \n'
#              '                    ',
#  'text_name': 'Физики заперли свет в нанорезонаторе на рекордно долгое время',
#  'text_url': 'https://nplus1.ru/news/2020/01/20/subwavelength-resonators'}

# %% [markdown]
# Посмотрим и на другие коллекции.

# %%
for t in dictionary.find()[:2]:
    pprint(t)
# Out:
# {'POS': 'NOUN',
#  '_id': ObjectId('616fcef4e3381e0ff188001e'),
#  'docs': [ObjectId('616fcef4e3381e0ff188001c')],
#  'freq': 1,
#  'iniForm': 'марсоход',
#  'token': 'Марсоход'}
# {'POS': 'NOUN',
#  '_id': ObjectId('616fcef4e3381e0ff1880021'),
#  'docs': [ObjectId('616fcef4e3381e0ff188001c'),
#           ObjectId('61ba0f43e48154e25857f07d')],
#  'freq': 3,
#  'iniForm': 'розалинда',
#  'token': 'Розалинд'}

# %%
for t in lemmas.find()[:2]:
    pprint(t)
# Out:
# {'POS': 'NOUN',
#  '_id': ObjectId('616fcef4e3381e0ff188001d'),
#  'docs': [ObjectId('616fcef4e3381e0ff188001c'),
#           ObjectId('61ba0f43e48154e25857f07d')],
#  'freq': 6,
#  'iniForm': 'марсоход'}
# {'POS': 'NOUN',
#  '_id': ObjectId('616fcef4e3381e0ff1880020'),
#  'docs': [ObjectId('616fcef4e3381e0ff188001c'),
#           ObjectId('61ba0f43e48154e25857f07d')],
#  'freq': 3,
#  'iniForm': 'розалинда'}

# %%
for t in dbsents.find()[:2]:
    pprint(t)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001f'),
#  'position': 1,
#  'sent_id': 1,
#  'textId': ObjectId('616fcef4e3381e0ff188001c'),
#  'wordFormId': ObjectId('616fcef4e3381e0ff188001e')}
# {'_id': ObjectId('616fcef4e3381e0ff1880022'),
#  'position': 2,
#  'sent_id': 1,
#  'textId': ObjectId('616fcef4e3381e0ff188001c'),
#  'wordFormId': ObjectId('616fcef4e3381e0ff1880021')}

# %% [markdown]
# Чтобы поиск производился быстрее можно создать индексы.

# %%
# Добавляем индекс в коллекцию lemmas по полям iniForm и POS, оба по возрастанию.
# Заодно запрещаем добавлять повторяющиеся сочетания.
lemmas.create_index([('iniForm', pymongo.ASCENDING), ('POS', pymongo.ASCENDING)], unique=True)
dictionary.create_index([('token', pymongo.ASCENDING), ('iniForm', pymongo.ASCENDING), ('POS', pymongo.ASCENDING)], unique=True)
# Out:
# 'token_1_iniForm_1_POS_1'

# %% [markdown]
# Или удалить их, если они больше не нужны.

# %%
# Для пробы чуть позже удалим индекс и посмотрим на изменение скорости работы.
lemmas.drop_index('iniForm_1_POS_1')

# %% [markdown]
# В качестве параметров функции передается документ (в случае Python - словарь) с полями и их значениями.
#
# Если значение должно отвечать не равенству, а другому условию, передается составное значение в виде словаря, ключем у которого будет обозначение оператора, а значением - значение с которым будет проводиться сравнение. Таких пар можно передать несколько.

# %%
# (freq _какое_ 2) _и_ (token _какое_ 'может')
#for l in dictionary.find({"freq": 2, 'token': 'может'}):
for l in dictionary.find({'token': 'ученые', 'freq': 15}):
    print(l)
# Out:
# {'_id': ObjectId('616fcef5e3381e0ff18802ae'), 'token': 'ученые', 'iniForm': 'учёный', 'POS': 'NOUN', 'freq': 15, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}

# %%
# freq _какое_ меньше _чего_ 5
for l in lemmas.find({"freq":{"$lt": 5}})[:5]:
    print(l)

print("----")
# freq _какое_ меньше _чего_ 5
for l in dictionary.find({"freq":{"$lt": 5}})[:5]:
    print(l)
    
print("----")
# freq _какое_ ((больше _чего_ 5) _и_ (меньше _чего_ 9))
for l in dictionary.find({"freq":{"$gt": 5, "$lt": 9}})[:5]:
    print(l)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff1880020'), 'iniForm': 'розалинда', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880023'), 'iniForm': 'франклин', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188002c'), 'iniForm': 'отправиться', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880032'), 'iniForm': 'красный', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880035'), 'iniForm': 'планета', 'POS': 'NOUN', 'freq': 4, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# ----
# {'_id': ObjectId('616fcef4e3381e0ff188001e'), 'token': 'Марсоход', 'iniForm': 'марсоход', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880021'), 'token': 'Розалинд', 'iniForm': 'розалинда', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880024'), 'token': 'Франклин', 'iniForm': 'франклин', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188002a'), 'token': 'должен', 'iniForm': 'должный', 'POS': 'ADJS', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef4e3381e0ff188002d'), 'token': 'отправиться', 'iniForm': 'отправиться', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# ----
# {'_id': ObjectId('616fcef4e3381e0ff1880027'), 'token': 'который', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff188005c'), 'token': 'которых', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800e6'), 'token': 'качестве', 'iniForm': 'качество', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880115'), 'token': 'будет', 'iniForm': 'быть', 'POS': 'VERB', 'freq': 8, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff188012d'), 'token': 'о', 'iniForm': 'о', 'POS': 'PREP', 'freq': 7, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}

# %%
text_collection.find({"_id":ObjectId('616fcefce3381e0ff188130d')})[0]
# Out:
# {'_id': ObjectId('616fcefce3381e0ff188130d'),
#  'text_url': 'https://nplus1.ru/news/2018/03/20/abel-prize-2018',
#  'text_name': 'Абелевская премия присуждена за открытие связи между теорией чисел и теорией представлений',
#  'art_text': 'Норвежская академия наук объявила лауреата Абелевской премии 2018 года. Им стал канадский математик\xa0Роберт Ленглендс. Премия присуждена «за дальновидную программу, соединяющую теорию представлений и теорию чисел».\xa0Абелевскую премию часто называют «Нобелевской премией по математике». В отличие от, например, Филдсовской медали она вручается каждый год. Размер премии — 6 миллионов крон (около 45 миллионов рублей). Церемония награждения пройдет 22 мая 2018 года в Университете Аула, Осло. Вручать награду будет лично король Норвегии Харальд V.\n    \n        \n                        \n                \n                    \n                        \n                    ',
#  'art_info': {'art_date': '20 Март 2018',
#   'art_time': '14:15',
#   'difficulty': '6.8',
#   'author': 'Владимир Королев'}}

# %%
# Можно записать и так.
# (freq _какое_ (больше _чего_ 5)() _и_ (freq _какое_ (меньше _чего_ 9))
for l in dictionary.find({"freq":{"$gt": 5}, "freq": {"$lt": 9}}):
    print(l)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001e'), 'token': 'Марсоход', 'iniForm': 'марсоход', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880021'), 'token': 'Розалинд', 'iniForm': 'розалинда', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880024'), 'token': 'Франклин', 'iniForm': 'франклин', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880027'), 'token': 'который', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff188002a'), 'token': 'должен', 'iniForm': 'должный', 'POS': 'ADJS', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef4e3381e0ff188002d'), 'token': 'отправиться', 'iniForm': 'отправиться', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880033'), 'token': 'Красной', 'iniForm': 'красный', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880036'), 'token': 'планете', 'iniForm': 'планета', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880039'), 'token': 'этим', 'iniForm': 'это', 'POS': 'NPRO', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188003c'), 'token': 'летом', 'iniForm': 'лето', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff188003f'), 'token': 'успешно', 'iniForm': 'успешно', 'POS': 'ADVB', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880042'), 'token': 'прошел', 'iniForm': 'пройти', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880045'), 'token': 'заключительные', 'iniForm': 'заключительный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880048'), 'token': 'термовакуумные', 'iniForm': 'термовакуумный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188004b'), 'token': 'испытания', 'iniForm': 'испытание', 'POS': 'NOUN', 'freq': 4, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef4e3381e0ff188004e'), 'token': 'имитировавшие', 'iniForm': 'имитировать', 'POS': 'PRTF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880051'), 'token': 'условия', 'iniForm': 'условие', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880054'), 'token': 'марсианской', 'iniForm': 'марсианский', 'POS': 'ADJF', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880057'), 'token': 'среды', 'iniForm': 'среда', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef4e3381e0ff188005c'), 'token': 'которых', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff188005f'), 'token': 'предстоит', 'iniForm': 'предстоять', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880062'), 'token': 'работать', 'iniForm': 'работать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880065'), 'token': 'роверу', 'iniForm': 'ровер', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880068'), 'token': 'сообщается', 'iniForm': 'сообщаться', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef4e3381e0ff188006e'), 'token': 'сайте', 'iniForm': 'сайт', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880071'), 'token': 'Старт', 'iniForm': 'старт', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880074'), 'token': 'второго', 'iniForm': 'второй', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880077'), 'token': 'этапа', 'iniForm': 'этап', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff188007a'), 'token': 'российско-европейской', 'iniForm': 'российско-европейский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188007d'), 'token': 'программы', 'iniForm': 'программа', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880080'), 'token': 'ЭкзоМарс', 'iniForm': 'экзомарс', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880083'), 'token': 'намечен', 'iniForm': 'наметить', 'POS': 'PRTS', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880087'), 'token': 'период', 'iniForm': 'период', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef4e3381e0ff188008d'), 'token': 'июля', 'iniForm': 'июль', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880093'), 'token': 'августа', 'iniForm': 'август', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880099'), 'token': 'Ракета-носитель', 'iniForm': 'ракета-носитель', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188009c'), 'token': 'Протон', 'iniForm': 'протон', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188009f'), 'token': 'выведет', 'iniForm': 'вывести', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800a3'), 'token': 'космос', 'iniForm': 'космос', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800a6'), 'token': 'перелетный', 'iniForm': 'перелётный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800a9'), 'token': 'модуль', 'iniForm': 'модуль', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800ad'), 'token': 'доставит', 'iniForm': 'доставить', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800b1'), 'token': 'Марсу', 'iniForm': 'марс', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800b4'), 'token': 'десантный', 'iniForm': 'десантный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800b8'), 'token': 'содержащий', 'iniForm': 'содержать', 'POS': 'PRTF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800bc'), 'token': 'себе', 'iniForm': 'себя', 'POS': 'NPRO', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800bf'), 'token': 'автономную', 'iniForm': 'автономный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800c2'), 'token': 'научную', 'iniForm': 'научный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800c5'), 'token': 'станцию', 'iniForm': 'станция', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800c8'), 'token': 'Казачок', 'iniForm': 'казачок', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800cd'), 'token': 'марсоход', 'iniForm': 'марсоход', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800d2'), 'token': 'Посадка', 'iniForm': 'посадка', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800d6'), 'token': 'поверхность', 'iniForm': 'поверхность', 'POS': 'NOUN', 'freq': 5, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800d9'), 'token': 'планеты', 'iniForm': 'планета', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800db'), 'token': 'должна', 'iniForm': 'должный', 'POS': 'ADJS', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800de'), 'token': 'состояться', 'iniForm': 'состояться', 'POS': 'INFN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800e1'), 'token': 'марта', 'iniForm': 'март', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800e6'), 'token': 'качестве', 'iniForm': 'качество', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800e9'), 'token': 'места', 'iniForm': 'место', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800ec'), 'token': 'работы', 'iniForm': 'работа', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcefbe3381e0ff18810a6')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800ef'), 'token': 'аппаратов', 'iniForm': 'аппарат', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800f2'), 'token': 'выбрана', 'iniForm': 'выбрать', 'POS': 'PRTS', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800f5'), 'token': 'равнина', 'iniForm': 'равнина', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800f8'), 'token': 'Оксия', 'iniForm': 'оксий', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800fc'), 'token': 'северном', 'iniForm': 'северный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800ff'), 'token': 'полушарии', 'iniForm': 'полушарие', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880101'), 'token': 'Марса', 'iniForm': 'марс', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880104'), 'token': 'где', 'iniForm': 'где', 'POS': 'ADVB', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880107'), 'token': 'есть', 'iniForm': 'есть', 'POS': 'INFN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff18807da')]}
# {'_id': ObjectId('616fcef4e3381e0ff188010a'), 'token': 'сухие', 'iniForm': 'сухой', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188010d'), 'token': 'русла', 'iniForm': 'русло', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880110'), 'token': 'Задачей', 'iniForm': 'задача', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880112'), 'token': 'марсохода', 'iniForm': 'марсоход', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880115'), 'token': 'будет', 'iniForm': 'быть', 'POS': 'VERB', 'freq': 8, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880118'), 'token': 'поиск', 'iniForm': 'поиск', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188011b'), 'token': 'соединений', 'iniForm': 'соединение', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff188011f'), 'token': 'веществ', 'iniForm': 'вещество', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880124'), 'token': 'могли', 'iniForm': 'мочь', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880127'), 'token': 'бы', 'iniForm': 'бы', 'POS': 'PRCL', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff188012a'), 'token': 'свидетельствовать', 'iniForm': 'свидетельствовать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188012d'), 'token': 'о', 'iniForm': 'о', 'POS': 'PREP', 'freq': 7, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880130'), 'token': 'возможном', 'iniForm': 'возможный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880133'), 'token': 'существовании', 'iniForm': 'существование', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880138'), 'token': 'жизни', 'iniForm': 'жизнь', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188013c'), 'token': 'прошлом', 'iniForm': 'прошлый', 'POS': 'ADJF', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880145'), 'token': 'изучение', 'iniForm': 'изучение', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880148'), 'token': 'геологии', 'iniForm': 'геология', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188014b'), 'token': 'Научная', 'iniForm': 'научный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188014d'), 'token': 'станция', 'iniForm': 'станция', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880150'), 'token': 'займется', 'iniForm': 'заняться', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880153'), 'token': 'исследованием', 'iniForm': 'исследование', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880156'), 'token': 'состава', 'iniForm': 'состав', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188015a'), 'token': 'свойств', 'iniForm': 'свойство', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188015c'), 'token': 'поверхности', 'iniForm': 'поверхность', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880160'), 'token': 'атмосферы', 'iniForm': 'атмосфера', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef9e3381e0ff1880e4b')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880167'), 'token': 'конце', 'iniForm': 'конец', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188016b'), 'token': 'была', 'iniForm': 'быть', 'POS': 'VERB', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef4e3381e0ff188016e'), 'token': 'завершена', 'iniForm': 'завершить', 'POS': 'PRTS', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880171'), 'token': 'сборка', 'iniForm': 'сборка', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880178'), 'token': 'чего', 'iniForm': 'что', 'POS': 'NPRO', 'freq': 5, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef4e3381e0ff188017e'), 'token': 'отправили', 'iniForm': 'отправить', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880182'), 'token': 'цеха', 'iniForm': 'цех', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880185'), 'token': 'компании', 'iniForm': 'компания', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880189'), 'token': 'Тулузе', 'iniForm': 'тулуза', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188018f'), 'token': 'прохождения', 'iniForm': 'прохождение', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880191'), 'token': 'заключительных', 'iniForm': 'заключительный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880194'), 'token': 'термических', 'iniForm': 'термический', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880198'), 'token': 'вакуумных', 'iniForm': 'вакуумный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188019a'), 'token': 'испытаний', 'iniForm': 'испытание', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff188019c'), 'token': 'имитирующих', 'iniForm': 'имитировать', 'POS': 'PRTF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801a1'), 'token': 'Аппарат', 'iniForm': 'аппарат', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801a5'), 'token': 'функционировать', 'iniForm': 'функционировать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801ab'), 'token': 'атмосферном', 'iniForm': 'атмосферный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801ae'), 'token': 'давлении', 'iniForm': 'давление', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801b1'), 'token': 'значение', 'iniForm': 'значение', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801b3'), 'token': 'которого', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801b6'), 'token': 'составляет', 'iniForm': 'составлять', 'POS': 'VERB', 'freq': 4, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801b9'), 'token': 'менее', 'iniForm': 'менее', 'POS': 'ADVB', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801bc'), 'token': 'одной', 'iniForm': 'один', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801bf'), 'token': 'сотой', 'iniForm': 'сотый', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801c5'), 'token': 'земного', 'iniForm': 'земной', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801c9'), 'token': 'низких', 'iniForm': 'низкий', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801cc'), 'token': 'температурах', 'iniForm': 'температура', 'POS': 'NOUN', 'freq': 4, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801cf'), 'token': 'Моделирование', 'iniForm': 'моделирование', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801d2'), 'token': 'показывает', 'iniForm': 'показывать', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801d8'), 'token': 'температуре', 'iniForm': 'температура', 'POS': 'NOUN', 'freq': 5, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801db'), 'token': 'окружающего', 'iniForm': 'окружающий', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801de'), 'token': 'воздуха', 'iniForm': 'воздух', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801e1'), 'token': 'градусов', 'iniForm': 'градус', 'POS': 'NOUN', 'freq': 8, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801e5'), 'token': 'Цельсию', 'iniForm': 'цельсий', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801e7'), 'token': 'температура', 'iniForm': 'температура', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801ea'), 'token': 'внутри', 'iniForm': 'внутри', 'POS': 'PREP', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801ec'), 'token': 'ровера', 'iniForm': 'ровер', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801ef'), 'token': 'составит', 'iniForm': 'составить', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801f8'), 'token': 'испытательная', 'iniForm': 'испытательный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801fa'), 'token': 'программа', 'iniForm': 'программа', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880201'), 'token': 'настоящее', 'iniForm': 'настоящий', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880207'), 'token': 'ведется', 'iniForm': 'вестись', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880209'), 'token': 'заключительное', 'iniForm': 'заключительный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188020c'), 'token': 'тестирование', 'iniForm': 'тестирование', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188020f'), 'token': 'всех', 'iniForm': 'весь', 'POS': 'ADJF', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880212'), 'token': 'систем', 'iniForm': 'система', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880215'), 'token': 'После', 'iniForm': 'после', 'POS': 'PREP', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880219'), 'token': 'окончания', 'iniForm': 'окончание', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188021b'), 'token': 'ровер', 'iniForm': 'ровер', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188021f'), 'token': 'перевезен', 'iniForm': 'перевезти', 'POS': 'PRTS', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880222'), 'token': 'компанию', 'iniForm': 'компания', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880226'), 'token': 'Каннах', 'iniForm': 'канны', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188022b'), 'token': 'проведена', 'iniForm': 'провести', 'POS': 'PRTS', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188022e'), 'token': 'проверка', 'iniForm': 'проверка', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880232'), 'token': 'совместимости', 'iniForm': 'совместимость', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880236'), 'token': 'посадочной', 'iniForm': 'посадочный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880239'), 'token': 'платформой', 'iniForm': 'платформа', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188023c'), 'token': 'десантным', 'iniForm': 'десантный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188023e'), 'token': 'модулем', 'iniForm': 'модуль', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880241'), 'token': 'Ранее', 'iniForm': 'ранее', 'POS': 'ADVB', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880244'), 'token': 'мы', 'iniForm': 'мы', 'POS': 'NPRO', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880247'), 'token': 'рассказывали', 'iniForm': 'рассказывать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188024b'), 'token': 'трудностях', 'iniForm': 'трудность', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188024e'), 'token': 'которыми', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880251'), 'token': 'пришлось', 'iniForm': 'прийтись', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880254'), 'token': 'столкнуться', 'iniForm': 'столкнуться', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880257'), 'token': 'специалистам', 'iniForm': 'специалист', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff188025b'), 'token': 'разработке', 'iniForm': 'разработка', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef4e3381e0ff188025e'), 'token': 'тормозной', 'iniForm': 'тормозной', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880260'), 'token': 'системы', 'iniForm': 'система', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880263'), 'token': 'ЭкзоМарса', 'iniForm': 'экзомарс', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880266'), 'token': 'Александр', 'iniForm': 'александр', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880269'), 'token': 'Войтюк', 'iniForm': 'войтюк', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef5e3381e0ff188026d'), 'token': 'Физики', 'iniForm': 'физика', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880270'), 'token': 'создали', 'iniForm': 'создать', 'POS': 'VERB', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880273'), 'token': 'резонатор', 'iniForm': 'резонатор', 'POS': 'NOUN', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880276'), 'token': 'размером', 'iniForm': 'размер', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188027a'), 'token': 'несколько', 'iniForm': 'несколько', 'POS': 'ADVB', 'freq': 7, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff188027d'), 'token': 'сотен', 'iniForm': 'сотня', 'POS': 'NOUN', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880280'), 'token': 'нанометров', 'iniForm': 'нанометр', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880283'), 'token': 'способный', 'iniForm': 'способный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880286'), 'token': 'удерживать', 'iniForm': 'удерживать', 'POS': 'INFN', 'freq': 5, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880289'), 'token': 'свет', 'iniForm': 'свет', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188028c'), 'token': 'себя', 'iniForm': 'себя', 'POS': 'NPRO', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880293'), 'token': 'которое', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880296'), 'token': 'световая', 'iniForm': 'световой', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880299'), 'token': 'волна', 'iniForm': 'волна', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188029c'), 'token': 'совершает', 'iniForm': 'совершать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188029f'), 'token': 'более', 'iniForm': 'более', 'POS': 'ADVB', 'freq': 8, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802a1'), 'token': 'периодов', 'iniForm': 'период', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802a4'), 'token': 'колебаний', 'iniForm': 'колебание', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802a6'), 'token': 'На', 'iniForm': 'на', 'POS': 'PREP', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802a9'), 'token': 'основе', 'iniForm': 'основа', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802ab'), 'token': 'него', 'iniForm': 'он', 'POS': 'NPRO', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802b2'), 'token': 'устройство', 'iniForm': 'устройство', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802b6'), 'token': 'увеличивает', 'iniForm': 'увеличивать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802b9'), 'token': 'частоту', 'iniForm': 'частота', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802bc'), 'token': 'входного', 'iniForm': 'входной', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802be'), 'token': 'света', 'iniForm': 'свет', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802c2'), 'token': 'два', 'iniForm': 'два', 'POS': 'NUMR', 'freq': 6, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802c5'), 'token': 'раза', 'iniForm': 'раз', 'POS': 'NOUN', 'freq': 5, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802ca'), 'token': 'будущем', 'iniForm': 'будущее', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefae3381e0ff1880ee4')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802cd'), 'token': 'такие', 'iniForm': 'такой', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802d0'), 'token': 'нанорезонаторы', 'iniForm': 'нанорезонатор', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802d2'), 'token': 'могут', 'iniForm': 'мочь', 'POS': 'VERB', 'freq': 5, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802d5'), 'token': 'стать', 'iniForm': 'стать', 'POS': 'INFN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802d7'), 'token': 'основой', 'iniForm': 'основа', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802db'), 'token': 'создания', 'iniForm': 'создание', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802de'), 'token': 'оптических', 'iniForm': 'оптический', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802e1'), 'token': 'средств', 'iniForm': 'средство', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802e4'), 'token': 'связи', 'iniForm': 'связь', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802e7'), 'token': 'приборов', 'iniForm': 'прибор', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802ea'), 'token': 'ночного', 'iniForm': 'ночной', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802ed'), 'token': 'видения', 'iniForm': 'видение', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802f1'), 'token': 'компактных', 'iniForm': 'компактный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802f4'), 'token': 'сенсоров', 'iniForm': 'сенсор', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802f6'), 'token': 'Работа', 'iniForm': 'работа', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefae3381e0ff1880ee4')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802f9'), 'token': 'опубликована', 'iniForm': 'опубликовать', 'POS': 'PRTS', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802fd'), 'token': 'журнале', 'iniForm': 'журнал', 'POS': 'NOUN', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff18802ff'), 'token': 'С', 'iniForm': 'с', 'POS': 'PREP', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880305'), 'token': 'электрооптики', 'iniForm': 'электрооптика', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188030b'), 'token': 'передавать', 'iniForm': 'передавать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188030e'), 'token': 'информацию', 'iniForm': 'информация', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880312'), 'token': 'расстояние', 'iniForm': 'расстояние', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880315'), 'token': 'считывать', 'iniForm': 'считывать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880319'), 'token': 'записывать', 'iniForm': 'записывать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188031c'), 'token': 'данные', 'iniForm': 'дать', 'POS': 'PRTF', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880321'), 'token': 'контроля', 'iniForm': 'контроль', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880326'), 'token': 'нужно', 'iniForm': 'нужно', 'POS': 'PRED', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880329'), 'token': 'уметь', 'iniForm': 'уметь', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188032e'), 'token': 'малой', 'iniForm': 'малый', 'POS': 'ADJF', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880331'), 'token': 'области', 'iniForm': 'область', 'POS': 'NOUN', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880334'), 'token': 'пространства', 'iniForm': 'пространство', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880338'), 'token': 'достаточно', 'iniForm': 'достаточно', 'POS': 'ADVB', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef5e3381e0ff188033b'), 'token': 'долгое', 'iniForm': 'долгий', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188033f'), 'token': 'Но', 'iniForm': 'но', 'POS': 'CONJ', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880342'), 'token': 'чем', 'iniForm': 'чем', 'POS': 'CONJ', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880345'), 'token': 'меньше', 'iniForm': 'маленький', 'POS': 'COMP', 'freq': 4, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880349'), 'token': 'тем', 'iniForm': 'тем', 'POS': 'CONJ', 'freq': 5, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef5e3381e0ff188034c'), 'token': 'сложнее', 'iniForm': 'сложный', 'POS': 'COMP', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188034f'), 'token': 'удержать', 'iniForm': 'удержать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880353'), 'token': 'нем', 'iniForm': 'немой', 'POS': 'ADJS', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880355'), 'token': 'волну', 'iniForm': 'волна', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880358'), 'token': 'До', 'iniForm': 'до', 'POS': 'PREP', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcef5e3381e0ff188035b'), 'token': 'сих', 'iniForm': 'сей', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff188035e'), 'token': 'пор', 'iniForm': 'пора', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880361'), 'token': 'добиться', 'iniForm': 'добиться', 'POS': 'INFN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880364'), 'token': 'приемлемого', 'iniForm': 'приемлемый', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880366'), 'token': 'времени', 'iniForm': 'время', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880369'), 'token': 'удержания', 'iniForm': 'удержание', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef5e3381e0ff188036e'), 'token': 'практике', 'iniForm': 'практика', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880371'), 'token': 'удавалось', 'iniForm': 'удаваться', 'POS': 'VERB', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880374'), 'token': 'лишь', 'iniForm': 'лишь', 'POS': 'PRCL', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880377'), 'token': 'резонатора', 'iniForm': 'резонатор', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880379'), 'token': 'размерами', 'iniForm': 'размер', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188037c'), 'token': 'превышающего', 'iniForm': 'превышать', 'POS': 'PRTF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff188037f'), 'token': 'длину', 'iniForm': 'длина', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880382'), 'token': 'электромагнитной', 'iniForm': 'электромагнитный', 'POS': 'ADJF', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880384'), 'token': 'волны', 'iniForm': 'волна', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880387'), 'token': 'Попытки', 'iniForm': 'попытка', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880389'), 'token': 'ученых', 'iniForm': 'учёный', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff188038c'), 'token': 'создать', 'iniForm': 'создать', 'POS': 'INFN', 'freq': 2, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# ...
# {'_id': ObjectId('616fcf00e3381e0ff1881c28'), 'token': 'Атлантике', 'iniForm': 'атлантика', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c31'), 'token': 'Несмотря', 'iniForm': 'несмотря', 'POS': 'PREP', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c38'), 'token': 'головоногих', 'iniForm': 'головоногий', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c3c'), 'token': 'описали', 'iniForm': 'описать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c40'), 'token': 'середине', 'iniForm': 'середина', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c47'), 'token': 'оставалось', 'iniForm': 'оставаться', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c4a'), 'token': 'неизвестным', 'iniForm': 'неизвестный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c4f'), 'token': 'выглядят', 'iniForm': 'выглядеть', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c56'), 'token': 'допускают', 'iniForm': 'допускать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c60'), 'token': 'крупному', 'iniForm': 'крупный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c62'), 'token': 'виду', 'iniForm': 'вид', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c6b'), 'token': 'К', 'iniForm': 'к', 'POS': 'PREP', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c6e'), 'token': 'сожалению', 'iniForm': 'сожаление', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c70'), 'token': 'образцов', 'iniForm': 'образец', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c78'), 'token': 'смогли', 'iniForm': 'смочь', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881c7b'), 'token': 'наблюдениям', 'iniForm': 'наблюдение', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881c7f'), 'token': 'неволе', 'iniForm': 'неволя', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881c84'), 'token': 'представителями', 'iniForm': 'представитель', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881c87'), 'token': 'рода', 'iniForm': 'род', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881c8c'), 'token': 'студенистая', 'iniForm': 'студенистый', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881c93'), 'token': 'содержаться', 'iniForm': 'содержаться', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881c9a'), 'token': 'производится', 'iniForm': 'производиться', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881c9d'), 'token': 'специальными', 'iniForm': 'специальный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ca0'), 'token': 'железами', 'iniForm': 'железа', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ca4'), 'token': 'мантийной', 'iniForm': 'мантийный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ca7'), 'token': 'полости', 'iniForm': 'полость', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881caa'), 'token': 'самок', 'iniForm': 'самка', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cac'), 'token': 'Сферы', 'iniForm': 'сфера', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881caf'), 'token': 'дают', 'iniForm': 'давать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cb1'), 'token': 'яйцам', 'iniForm': 'яйцо', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cb4'), 'token': 'опуститься', 'iniForm': 'опуститься', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cb8'), 'token': 'дно', 'iniForm': 'дно', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cbc'), 'token': 'те', 'iniForm': 'тот', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cbe'), 'token': 'остаются', 'iniForm': 'оставаться', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cc6'), 'token': 'оптимальна', 'iniForm': 'оптимальный', 'POS': 'ADJS', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ccb'), 'token': 'развития', 'iniForm': 'развитие', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cd1'), 'token': 'потомство', 'iniForm': 'потомство', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cd9'), 'token': 'инфекций', 'iniForm': 'инфекция', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cdd'), 'token': 'ему', 'iniForm': 'он', 'POS': 'NPRO', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ce3'), 'token': 'течений', 'iniForm': 'течение', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ce7'), 'token': 'функция', 'iniForm': 'функция', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ce9'), 'token': 'темной', 'iniForm': 'тёмный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881ceb'), 'token': 'полосы', 'iniForm': 'полоса', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cee'), 'token': 'сферах', 'iniForm': 'сфера', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cf1'), 'token': 'остается', 'iniForm': 'оставаться', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cf3'), 'token': 'неизвестной', 'iniForm': 'неизвестный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cf6'), 'token': 'вероятно', 'iniForm': 'вероятно', 'POS': 'CONJ', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cf9'), 'token': 'состоит', 'iniForm': 'состоять', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881cfd'), 'token': 'меланина', 'iniForm': 'меланин', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d01'), 'token': 'имитирует', 'iniForm': 'имитировать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d03'), 'token': 'крупную', 'iniForm': 'крупный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d06'), 'token': 'рыбу', 'iniForm': 'рыба', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d09'), 'token': 'заставляя', 'iniForm': 'заставлять', 'POS': 'GRND', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d0c'), 'token': 'врагов', 'iniForm': 'враг', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d0f'), 'token': 'держаться', 'iniForm': 'держаться', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d12'), 'token': 'подальше', 'iniForm': 'далёкий', 'POS': 'COMP', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d14'), 'token': 'Срок', 'iniForm': 'срок', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d16'), 'token': 'существования', 'iniForm': 'существование', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d18'), 'token': 'защитных', 'iniForm': 'защитный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d1c'), 'token': 'недолог', 'iniForm': 'недолгий', 'POS': 'ADJS', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d1e'), 'token': 'Через', 'iniForm': 'через', 'POS': 'PREP', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d21'), 'token': 'пять-семь', 'iniForm': 'пять-семь', 'POS': 'NUMR', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d25'), 'token': 'вышедшие', 'iniForm': 'выйти', 'POS': 'PRTF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d2a'), 'token': 'юные', 'iniForm': 'юный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d2c'), 'token': 'кальмары', 'iniForm': 'кальмар', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d2e'), 'token': 'начинают', 'iniForm': 'начинать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d31'), 'token': 'выделять', 'iniForm': 'выделять', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d33'), 'token': 'специальный', 'iniForm': 'специальный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d36'), 'token': 'фермент', 'iniForm': 'фермент', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d3a'), 'token': 'растворяет', 'iniForm': 'растворять', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d3c'), 'token': 'защитную', 'iniForm': 'защитный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d3e'), 'token': 'оболочку', 'iniForm': 'оболочка', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d42'), 'token': 'открывает', 'iniForm': 'открывать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d45'), 'token': 'путь', 'iniForm': 'путь', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d48'), 'token': 'наружу', 'iniForm': 'наружу', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d4a'), 'token': 'Яйца', 'iniForm': 'яйцо', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d4f'), 'token': 'самый', 'iniForm': 'самый', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d51'), 'token': 'странный', 'iniForm': 'странный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d55'), 'token': 'даров', 'iniForm': 'дар', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d58'), 'token': 'Часто', 'iniForm': 'часто', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d5d'), 'token': 'пляжах', 'iniForm': 'пляж', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d60'), 'token': 'находят', 'iniForm': 'находить', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d63'), 'token': 'столь', 'iniForm': 'столь', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d66'), 'token': 'необычные', 'iniForm': 'необычный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d6b'), 'token': 'над', 'iniForm': 'над', 'POS': 'PREP', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d6e'), 'token': 'загадкой', 'iniForm': 'загадка', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d72'), 'token': 'происхождения', 'iniForm': 'происхождение', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d76'), 'token': 'поломать', 'iniForm': 'поломать', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d78'), 'token': 'голову', 'iniForm': 'голова', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d7a'), 'token': 'Мы', 'iniForm': 'мы', 'POS': 'NPRO', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d7d'), 'token': 'собрали', 'iniForm': 'собрать', 'POS': 'VERB', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d82'), 'token': 'примеров', 'iniForm': 'пример', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d86'), 'token': 'нашем', 'iniForm': 'наш', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d88'), 'token': 'тесте', 'iniForm': 'тест', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d8b'), 'token': 'Пляжный', 'iniForm': 'пляжный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d8e'), 'token': 'детектив', 'iniForm': 'детектив', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d91'), 'token': 'Сергей', 'iniForm': 'сергей', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcf01e3381e0ff1881d94'), 'token': 'Коленов', 'iniForm': 'колен', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}

# %%
res1 = lemmas.find({"freq":{"$gt": 5}})
res1[0]['iniForm'], type(res1[0])
# Out:
# ('который', dict)

# %% [markdown]
# Попробуем найти все документы со сложностью равной 2.3 (статья про ЭкзоМарс).

# %%
for l in text_collection.find({'art_info': {'difficulty': '2.3'}}):
    print(l)

# %%
text_collection.find({'art_info': {'art_date': '20 Март 2018',
  'art_time': '14:15',
  'difficulty': '6.8',
  'author': 'Владимир Королев'}})[0]
# Out:
# {'_id': ObjectId('616fcefce3381e0ff188130d'),
#  'text_url': 'https://nplus1.ru/news/2018/03/20/abel-prize-2018',
#  'text_name': 'Абелевская премия присуждена за открытие связи между теорией чисел и теорией представлений',
#  'art_text': 'Норвежская академия наук объявила лауреата Абелевской премии 2018 года. Им стал канадский математик\xa0Роберт Ленглендс. Премия присуждена «за дальновидную программу, соединяющую теорию представлений и теорию чисел».\xa0Абелевскую премию часто называют «Нобелевской премией по математике». В отличие от, например, Филдсовской медали она вручается каждый год. Размер премии — 6 миллионов крон (около 45 миллионов рублей). Церемония награждения пройдет 22 мая 2018 года в Университете Аула, Осло. Вручать награду будет лично король Норвегии Харальд V.\n    \n        \n                        \n                \n                    \n                        \n                    ',
#  'art_info': {'art_date': '20 Март 2018',
#   'art_time': '14:15',
#   'difficulty': '6.8',
#   'author': 'Владимир Королев'}}

# %% [markdown]
# Ничего не найдено, так как такая запись предполагает полное совпадение, то есть поиск поддокумента с единственным полем и этим значением. Если полей будет несколько, роль будет играть даже порядок следования полей в базе!
#
# То, что мы хотели сделать,нужно сделать вот так.

# %%
for l in text_collection.find({'art_info.difficulty': '2.3'}):
    print(l)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'), 'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes', 'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания', 'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к Красной планете этим летом, успешно прошел заключительные термовакуумные испытания, имитировавшие\xa0условия марсианской среды, в которых предстоит работать роверу,\xa0сообщается на сайте ESA.Старт второго этапа российско-европейской программы «ЭкзоМарс» намечен на период с 26 июля по 11 августа 2020 года. Ракета-носитель «Протон» выведет в космос перелетный модуль, который доставит к Марсу десантный модуль, содержащий в себе автономную научную станцию «Казачок»\xa0и марсоход «Розалинд Франклин». Посадка на поверхность Красной планеты должна состояться 19 марта 2021 года, в качестве места работы аппаратов выбрана\xa0равнина Оксия в северном полушарии Марса, где есть сухие русла. Задачей марсохода будет\xa0поиск соединений и веществ, которые могли бы свидетельствовать о возможном существовании на планете жизни в прошлом, а также изучение геологии Марса. Научная станция займется исследованием\xa0состава и свойств поверхности и атмосферы Красной планеты.В конце августа 2018 года была завершена сборка марсохода, после чего его отправили в цеха компании\xa0Airbus в Тулузе для прохождения заключительных термических и вакуумных испытаний, имитирующих условия марсианской среды. Аппарат должен функционировать\xa0при атмосферном давлении, значение которого составляет менее одной сотой от земного, и низких температурах. Моделирование показывает, что при температуре окружающего воздуха\xa0–120 градусов по Цельсию, температура внутри ровера составит –50 градусов по Цельсию.\xa0В конце 2019 года испытательная программа была успешно завершена, в настоящее время ведется заключительное тестирование всех систем марсохода. После его окончания ровер будет перевезен в компанию\xa0Thales Alenia Space в Каннах, где будет проведена проверка его совместимости с посадочной платформой и десантным модулем.Ранее мы рассказывали о трудностях, с которыми пришлось столкнуться специалистам при разработке тормозной системы для\xa0«ЭкзоМарса-2020».Александр Войтюк\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '20 Янв. 2020', 'art_time': '14:18', 'difficulty': '2.3', 'author': 'Александр Войтюк'}, 'coord': {'type': 'Point', 'coordinates': [20, 15]}}
# {'_id': ObjectId('616fcefbe3381e0ff188112d'), 'text_url': 'https://nplus1.ru/news/2018/03/20/balance', 'text_name': 'Вентиляторы в ногах помогли роботу перешагнуть пропасть', 'art_text': 'Инженеры создали робота с вентиляторными движителями в стопах для преодоления больших препятствий. При широком шаге вентилятор компенсирует вес ноги и позволяет роботу удерживать равновесие. Испытания показали, что робот может преодолевать препятствия длиной до 80\xa0процентов длины ноги, сообщается в\xa0работе, о\xa0которой рассказывает IEEE Spectrum.Шагающие роботы способны преодолевать небольшие препятствия и двигаться по неровным поверхностям, но чтобы сохранить равновесие, им приходится сокращать длину шага. Дело в том, что при большом отклонении ноги роботу сложно удерживать равновесие из-за сильного смещения центра тяжести. Для решения этой проблемы предлагаются разные способы, например, активная компенсация изменения центра тяжести с движениями руками и телом, но это сильно усложняет конструкцию робота и алгоритмы его управления.Инженеры под руководством Юня Чжана (Yun Zhang) из Гуандунского технологического университета предложили использовать для компенсации смещения центра тяжести при больших шагах вентиляторы. Для проверки концепции разработчики создали двуногого робота\xa0Jet-HR1 высотой 65 сантиметров и длиной ног 46 сантиметров. В нижнем сегменте каждой ноги установлен вентилятор с кольцевым обтекателем. Он может выдавать тягу в два килограмма при том, что общий вес робота составляет 6,5 килограммов.Инженеры разработали алгоритм балансировки робота с помощью вентиляторов. Поскольку скорость движения всех частей ног довольно мала, исследователи пренебрегли ей и принимали в расчет только силу притяжения и тягу вентиляторов. Во время движения ноги робот постоянно подстраивает тягу двигателя для удержания ноги. После того, как передняя нога оказывается на нужном месте, робот подтягивает вторую ногу таким же образом. Исследователи показали, как робот может перешагивать через большие препятствия с длиной до 80 процентов от длины ноги:Некоторые продвинутые роботы могут удерживать баланс и без таких приспособлений. Например, в 2016 году Boston Dynamics показала испытания гуманоидного робота Atlas, во время которых он стоял на одной ноге, поддерживая равновесия движениями рук и корпуса подобно людям.Григорий Копиев\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '20 Март 2018', 'art_time': '13:36', 'difficulty': '2.3', 'author': 'Григорий Копиев'}}

# %% [markdown]
# Можно выбирать не все поля, а только те, которые нам необходимы.

# %%
for t in text_collection.find(projection=['art_info.difficulty','text_name']):
    print(t)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'), 'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания', 'art_info': {'difficulty': '2.3'}}
# {'_id': ObjectId('616fcef5e3381e0ff188026b'), 'text_name': 'Физики заперли свет в нанорезонаторе на рекордно долгое время', 'art_info': {'difficulty': '4.2'}}
# {'_id': ObjectId('616fcef6e3381e0ff1880558'), 'text_name': 'Пилотируемый полет Crew Dragon к МКС состоится в первой половине 2020 года', 'art_info': {'difficulty': '1.7'}}
# {'_id': ObjectId('616fcef6e3381e0ff18807da'), 'text_name': 'Сон помог вознаграждению улучшить зрительное обучение', 'art_info': {'difficulty': '3.9'}}
# {'_id': ObjectId('616fcef8e3381e0ff1880c75'), 'text_name': 'Машинное обучение помогло распознать человека по танцу', 'art_info': {'difficulty': '1.9'}}
# {'_id': ObjectId('616fcef9e3381e0ff1880e4b'), 'text_name': 'Астрономы провели разведку для «Юноны»', 'art_info': {'difficulty': '2.7'}}
# {'_id': ObjectId('616fcefae3381e0ff1880ee4'), 'text_name': 'Астрономы внезапно нашли сонаправленные джеты', 'art_info': {'difficulty': '3.3'}}
# {'_id': ObjectId('616fcefbe3381e0ff18810a6'), 'text_name': 'Астрономы провели самый глубокий обзор Вселенной', 'art_info': {'difficulty': '4.7'}}
# {'_id': ObjectId('616fcefbe3381e0ff188112d'), 'text_name': 'Вентиляторы в ногах помогли роботу перешагнуть пропасть', 'art_info': {'difficulty': '2.3'}}
# {'_id': ObjectId('616fcefce3381e0ff188130d'), 'text_name': 'Абелевская премия присуждена за открытие связи между теорией чисел и теорией представлений', 'art_info': {'difficulty': '6.8'}}
# {'_id': ObjectId('616fcefce3381e0ff18813a0'), 'text_name': 'Бактерии помогли получить катализатор для электролиза воды', 'art_info': {'difficulty': '5.1'}}
# {'_id': ObjectId('616fcefee3381e0ff1881767'), 'text_name': 'Физики объяснили низкую скользкость льда при приближении к температуре плавления', 'art_info': {'difficulty': '3.4'}}
# {'_id': ObjectId('616fceffe3381e0ff18819c7'), 'text_name': 'Гигантские студенистые сферы из Атлантики оказались скоплениями яиц кальмаров', 'art_info': {'difficulty': '2.1'}}

# %% [markdown]
# Для поиска в массивах одного значения можно просто проводить поиск, БД сама будет искать объекты в массиве.
#
# Если мы ищем несколько значений в массиве, необходимо использовать соответствующие предикаты: `$in` для поиска вхождения одного из элементов, `$all` - поиска всех элементов, и т.д.
#
# Обратите внимание, для поиска мы используем не строку, а объект `ObjectId`, импортированный из библиотеки `bson`.
#
# Помимо этого, во втором цикле в поле projection мы передаем не только какие поля надо выводить, но и какие поля выводить не надо. Так, поле \_id, хранящее идентификатор документа, по умолчанию должно выводиться. В примере ниже оно подавляется при помощи `"_id":False`.

# %%
for l in dictionary.find({'token': 'ученые'}):
    print(l)
    print(l['docs'][0])
    for d in dictionary.find({"docs": {"$in":[l['docs'][0]]}})[:5]:
        print(d)
# Out:
# {'_id': ObjectId('616fcef5e3381e0ff18802ae'), 'token': 'ученые', 'iniForm': 'учёный', 'POS': 'NOUN', 'freq': 15, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# 616fcef5e3381e0ff188026b
# {'_id': ObjectId('616fcef4e3381e0ff1880030'), 'token': 'к', 'iniForm': 'к', 'POS': 'PREP', 'freq': 23, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880057'), 'token': 'среды', 'iniForm': 'среда', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef4e3381e0ff188005a'), 'token': 'в', 'iniForm': 'в', 'POS': 'PREP', 'freq': 152, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff188006b'), 'token': 'на', 'iniForm': 'на', 'POS': 'PREP', 'freq': 89, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880087'), 'token': 'период', 'iniForm': 'период', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}

# %%
for d in dictionary.find({"docs": ObjectId('616fcef5e3381e0ff188026b')})[:5]:
    print(d)
    
print("-----")
for d in dictionary.find({"docs": {"$in": [ObjectId('616fcef5e3381e0ff188026b')]}})[:5]:
    print(d)
    
print("-----")
for d in dictionary.find({"docs": {"$all": [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef9e3381e0ff1880e4b')]}},
                         projection={"_id":False, "token":True, "docs":True}):
    print(d)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff1880030'), 'token': 'к', 'iniForm': 'к', 'POS': 'PREP', 'freq': 23, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880057'), 'token': 'среды', 'iniForm': 'среда', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef4e3381e0ff188005a'), 'token': 'в', 'iniForm': 'в', 'POS': 'PREP', 'freq': 152, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff188006b'), 'token': 'на', 'iniForm': 'на', 'POS': 'PREP', 'freq': 89, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880087'), 'token': 'период', 'iniForm': 'период', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}
# -----
# {'_id': ObjectId('616fcef4e3381e0ff1880030'), 'token': 'к', 'iniForm': 'к', 'POS': 'PREP', 'freq': 23, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880057'), 'token': 'среды', 'iniForm': 'среда', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef4e3381e0ff188005a'), 'token': 'в', 'iniForm': 'в', 'POS': 'PREP', 'freq': 152, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff188006b'), 'token': 'на', 'iniForm': 'на', 'POS': 'PREP', 'freq': 89, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880087'), 'token': 'период', 'iniForm': 'период', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b')]}
# -----
# {'token': 'к', 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'в', 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'на', 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'с', 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'и', 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'помощью', 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'были', 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'из', 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'token': 'под', 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'token': 'руководством', 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}

# %%
# А это мы просто смотрим сколько текстов добавили в базу.
# В качестве параметра передается условие, считаются только удовлетворяющие ему документы.
# В данном случае нам нужны все.
print(text_collection.count_documents({}))

# Ищем количество слов с частотой встречаемости от 6 до 9.
print(lemmas.count_documents({"freq":{"$gt": 5, "$lt": 10}}))

# Здесь ищем слова с частотой встречаемости от 6 до 9, 
# просим не выводить идентификатор и отсортировать всё по частоте.
for l in lemmas.find({"freq":{"$gt": 5, "$lt": 10}}, {"_id":False}).sort("iniForm")[:5]:
    print(l)
print("----")
# Здесь ищем слова с частотой встречаемости от 6 до 9, 
# просим вывести токен и частоту, но не выводить идентификатор и отсортировать всё по частоте.
for l in dictionary.find({"freq":{"$gt": 5}}, {"token": True, "freq":True, "_id":False}, 
                         skip=25, limit=5).sort("freq"):
    print(l)
# Out:
# 13
# 62
# {'iniForm': 'автор', 'POS': 'NOUN', 'freq': 9, 'docs': [ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'iniForm': 'более', 'POS': 'ADVB', 'freq': 8, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'iniForm': 'больший', 'POS': 'ADJF', 'freq': 7, 'docs': [ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'iniForm': 'волна', 'POS': 'NOUN', 'freq': 8, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'iniForm': 'второй', 'POS': 'ADJF', 'freq': 8, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fceffe3381e0ff18819c7')]}
# ----
# {'token': 'сфер', 'freq': 6}
# {'token': 'бактерий', 'freq': 6}
# {'token': 'было', 'freq': 6}
# {'token': 'группе', 'freq': 6}
# {'token': 'руководством', 'freq': 7}

# %% [markdown]
# Теперь напишем функцию для того, чтобы класть статью в БД. используем для этого функции:
# - insert_one (insert, insert_many) - добавляет запись (несколько записей) в выбранную коллекцию.
# - find_one_and_update - найти и обновить (аналог update).
#
# В качестве параметра во все функции добавления передается документ (словарь), ключи которого содержат названия полей, а значения - значения этих полей. Значение поля само может являться документом. При поиске часть полей может принимать особые значения, например, `$ne` - не равно, `$size` - смотрим на размер массива, `$inc` - увеличить значение поля на заданную величину и т.д. Более подробно с соответствующими ключами можно ознакомиться <a href="https://metanit.com/nosql/mongodb/" >здесь</a>.

# %%
for d in dictionary.find({"docs": {"$size": 1}})[:5]:
    print(d)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001e'), 'token': 'Марсоход', 'iniForm': 'марсоход', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880021'), 'token': 'Розалинд', 'iniForm': 'розалинда', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880024'), 'token': 'Франклин', 'iniForm': 'франклин', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff188002d'), 'token': 'отправиться', 'iniForm': 'отправиться', 'POS': 'INFN', 'freq': 1, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880033'), 'token': 'Красной', 'iniForm': 'красный', 'POS': 'ADJF', 'freq': 3, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}

# %%
# Создаем морфоанализатор.
morph = pymorphy2.MorphAnalyzer()

# %%
class NPlus1Article:
    def __init__(self):
        self.time = ""
        self.date = ""
        self.rubr = ""
        self.diff = ""
        self.author = ""
        self.head = ""
        self.text = ""
        
    def __repr__(self) -> str:
        return f"{self.head}, {self.author}, {self.date}, {self.rubr}, {self.text}"

def getArticleTextNPlus1(adr):
    page = requests.get(adr)
    #print(r.text)
    art=NPlus1Article()
    tree = html.fromstring(page.text)
    art.head = tree.xpath(".//h1")[0].text_content()
    dt = tree.xpath(".//time//span")
    art.date = dt[1].text_content()
    art.time = dt[0].text_content()
    art.rubr = tree.xpath(".//a[@data-rubric]")[0].text_content()
    art.diff = tree.xpath(".//span[@class='difficult-value']")[0].text_content()
    art.author = tree.xpath(".//meta[@name='mediator_author']")[0].get("content")
    art.text = '\n'.join([p.text_content() for p in tree.xpath(".//article//p")[3:-2]])
    
    
#     tables=re.split("</div>", re.split('="tables"', r.text)[1])[0]
#     t1=re.split("</time>", re.split("<time", tables)[1])[0]
#     art.time=re.split("</span>", re.split("<span>", t1)[1])[0]
#     art.date=re.split("</span>", re.split("<span>", t1)[2])[0]
#     art.rubr=re.split(">", re.split("</a>", re.split("<a href", tables)[1])[0])[1]
#     art.diff=re.split("</span>", re.split('"difficult-value">', tables)[1])[0]
#     art.head=re.split("</h1>", re.split('<h1>', r.text)[1])[0]
#     art.author=re.split('" />', re.split('<meta name="author" content="', r.text)[1])[0]
#     art.text=re.split("</div>", re.split("</figure>", re.split('</article>',re.split('<article', r.text)[1])[0])[1])[1]    

#     beaux_text=BeautifulSoup(art.text, "html5lib")
#     art.text=delcom.sub("", beaux_text.get_text() )

    # print(art.n_time, art.n_date, art.n_rubr, art.n_diff)
    # print(art.n_head)
    # print(art.n_author)
    # print(art.n_text)
    #return [n_time, n_date, n_rubr, n_diff, n_author, n_head, n_text]
    return art

def putNPlus1ArticleInMongo(art_url):
    # Загружаем текст статьи и другие ее части.
    art = getArticleTextNPlus1(art_url) 

    # Добавляем запись с информацией о статье.
    # inserted_id позволяет сразу получить идентификатор записи, чтобы потом ссылаться на него там, где это необходимо.
    a_text = {"text_url": art_url, "text_name": art.head, "art_text": art.text, 
              "art_info": {"art_date": art.date, "art_time": art.time, 
                           "difficulty": art.diff, "author": art.author}}
    text_id = text_collection.insert_one(a_text).inserted_id
    print(text_id)

    # Выделяем предложения (просто по точке с пробелом или в конце строки!!!).
    sents = re.split("\.\s|\.$", art.text)
    sent_num = 1
    # Загружаем предложения в базу.
    for s in tqdm(sents):
        # Выделяем слова (просто как группы русских букв!!!).
        words = re.findall("([А-Яа-я]+(\-[А-Яа-я]+)?)", s)
        posit = 1
        # Загрузка слов из предложений.
        for w in words:
            wf = morph.parse(w[0])
            # Провели морфологический анализ и теперь добавляем документ с двумя полями: нач. форма и часть речи.
            # Сперва проверяем есть ли там уже такая запись.
            # Смотрим сколько таких слов нашлось. Если ни одного - надо добавлять.
            if lemmas.count_documents({"iniForm": wf[0].normal_form, "POS": wf[0].tag.POS}) == 0:
                lemma_id = lemmas.insert_one({"iniForm": wf[0].normal_form, "POS": wf[0].tag.POS, 
                                              "freq": 1, "docs":[text_id]}).inserted_id
            # А если такое слово уже было, то обновляем частоту встречаемости и в каком документе оно встретиось.
            else:
                inis = lemmas.find({"iniForm": wf[0].normal_form, "POS": wf[0].tag.POS})
                lemma_id = inis[0]["_id"]
#                 lemmas.find_one_and_update({"_id": lemma_id}, {"$inc": {"freq":1}})
#                 lemmas.find_one_and_update({"_id": lemma_id}, {"$addToSet": {"docs": text_id}}) 
                lemmas.find_one_and_update({"_id": lemma_id}, 
                                           {"$inc": {"freq": 1}, 
                                            "$addToSet": {"docs": text_id}})
                # Вот таким образом можно добавлять номер документа столько раз, сколько в нем встретилось слово.
                #lemmas.find_one_and_update({"_id": lemma_id}, {"$push": {"docs": text_id}}) 

            # Повторяем операцию для токенов.
            if dictionary.count_documents({"token":w[0], "iniForm": wf[0].normal_form, "POS": wf[0].tag.POS}) == 0:
                wf_id = dictionary.insert_one({"token":w[0], 
                                               "iniForm": wf[0].normal_form, 
                                               "POS": wf[0].tag.POS, 
                                               "freq": 1, 
                                               "docs": [text_id]}).inserted_id
            else:
                wrdf = dictionary.find({"token": w[0], "iniForm": wf[0].normal_form, "POS": wf[0].tag.POS})
                wf_id=wrdf[0]["_id"]
                dictionary.find_one_and_update({"_id": wf_id}, {"$inc":  {"freq": 1}}) 
                dictionary.find_one_and_update({"_id": wf_id}, {"$addToSet": {"docs": text_id}}) 
  
            # Добавляем номер предложения, идентификатор словоформы из словаря, позицию слова, из какого оно текста.
            dbsents.insert_one({"sent_id": sent_num, "wordFormId":wf_id, "position": posit, "textId": text_id})
            posit += 1  
        sent_num += 1

# %%
# Добавляем статью  в базу.
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/20/subwavelength-resonators")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/20/crew-dragon-first-crewed-flight")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/18/visual-perception")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/01/18/dancing-recognition")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2016/06/27/juno-pictures")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2016/04/12/alignment-of-jets")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2016/06/29/Ultra-Deep-Survey")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2018/03/20/balance")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2018/03/20/abel-prize-2018")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2020/10/12/srb-electrode")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2021/02/19/friction-on-ice")
# putNPlus1ArticleInMongo("https://nplus1.ru/news/2021/04/07/illex-coindetii")
putNPlus1ArticleInMongo("https://nplus1.ru/news/2021/12/15/parachute-exomars-2022")
# Out:
# 61ba0f43e48154e25857f07d
# 100%|███████████████████████████████████████████| 18/18 [00:00<00:00, 23.59it/s]

# %%
# Вот так можно удалить всё в базе. Если написать условие, то не всё. 
# Экспериментировать не будем, да?
text_collection.delete_many({})
dictionary.delete_many({})
lemmas.delete_many({})
dbsents.delete_many({})
#for l in dbsents.find():
# print(l)

# %%
# Так можно посмотреть все записи, у которых в токене записан список ровно из пяти элементов.
#for l in dictionary.find({"docs":{"$size":5}})[:5]:
for l in dictionary.find({"docs":{"$size":4}})[:5]:
    print(l)
print("=====")
# Так можно посмотреть все записи, у которых есть поле docs.
for l in lemmas.find({"docs":{"$exists":True}})[:5]:
    print(l)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff1880027'), 'token': 'который', 'iniForm': 'который', 'POS': 'ADJF', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff18800e6'), 'token': 'качестве', 'iniForm': 'качество', 'POS': 'NOUN', 'freq': 6, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880178'), 'token': 'чего', 'iniForm': 'что', 'POS': 'NPRO', 'freq': 5, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801b6'), 'token': 'составляет', 'iniForm': 'составлять', 'POS': 'VERB', 'freq': 4, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# {'_id': ObjectId('616fcef4e3381e0ff18801e1'), 'token': 'градусов', 'iniForm': 'градус', 'POS': 'NOUN', 'freq': 8, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcefbe3381e0ff18810a6'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# =====
# {'_id': ObjectId('616fcef4e3381e0ff188001d'), 'iniForm': 'марсоход', 'POS': 'NOUN', 'freq': 5, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880020'), 'iniForm': 'розалинда', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880023'), 'iniForm': 'франклин', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef4e3381e0ff188001c')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880026'), 'iniForm': 'который', 'POS': 'ADJF', 'freq': 46, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef4e3381e0ff1880029'), 'iniForm': 'должный', 'POS': 'ADJS', 'freq': 7, 'docs': [ObjectId('616fcef4e3381e0ff188001c'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefce3381e0ff18813a0')]}

# %% [markdown]
# При помощи ключевого слова `$regex' можно искать в базе строки, отвечающие регулярным выражениям.

# %%
# iniForm _какое_ описывается_регуляркой _какой_ ^и.+
for d in lemmas.find({'iniForm':{'$regex':'^и.+'}})[:5]:
    print(d)
print("====")    
for d in dictionary.find({'token':{'$regex':'^[А-Я].+'}})[:5]:
    print(d)
# Out:
# {'_id': ObjectId('616fcef8e3381e0ff1880c72'), 'iniForm': 'ивтушок', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef6e3381e0ff18807da')]}
# {'_id': ObjectId('616fcef7e3381e0ff1880834'), 'iniForm': 'играть', 'POS': 'VERB', 'freq': 2, 'docs': [ObjectId('616fcef6e3381e0ff18807da')]}
# {'_id': ObjectId('616fcef6e3381e0ff188076b'), 'iniForm': 'идея', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef5e3381e0ff18803bd'), 'iniForm': 'из', 'POS': 'PREP', 'freq': 28, 'docs': [ObjectId('616fcef5e3381e0ff188026b'), ObjectId('616fcef6e3381e0ff1880558'), ObjectId('616fcef6e3381e0ff18807da'), ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcef9e3381e0ff1880e4b'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcefbe3381e0ff18811b7'), 'iniForm': 'из-за', 'POS': 'PREP', 'freq': 3, 'docs': [ObjectId('616fcefbe3381e0ff188112d'), ObjectId('616fcefce3381e0ff18813a0'), ObjectId('616fcefee3381e0ff1881767')]}
# ====
# {'_id': ObjectId('616fcefce3381e0ff188131d'), 'token': 'Абелевской', 'iniForm': 'абелёвский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcefce3381e0ff188130d')], 'found': 'true'}
# {'_id': ObjectId('616fcefce3381e0ff1881349'), 'token': 'Абелевскую', 'iniForm': 'абелёвский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcefce3381e0ff188130d')]}
# {'_id': ObjectId('616fcef5e3381e0ff18803c5'), 'token': 'Австралии', 'iniForm': 'австралия', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880434'), 'token': 'Австралийского', 'iniForm': 'австралийский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcefde3381e0ff1881607'), 'token': 'Авторам', 'iniForm': 'автор', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcefce3381e0ff18813a0')]}

# %% [markdown]
# Ключевое слово `$or` и другие операторы позволяют применять логические свзки помимо логического И.

# %%
# _или_по_списку_условий_ [token _какой_ описывается_регуляркой _какой_ ^И.+, 
#                          token _какой_ описывается_регуляркой _какой_ .+ъ.+]
for d in dictionary.find({'$and':[{'token':{'$regex':'^о.+'}}, {'token':{'$regex':'.+ъ.+'}}, {'freq':2}]})[:5]:
    print(d)
# Out:
# {'_id': ObjectId('616fcef9e3381e0ff1880db3'), 'token': 'объекты', 'iniForm': 'объект', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcefee3381e0ff18817a7'), 'token': 'объяснить', 'iniForm': 'объяснить', 'POS': 'INFN', 'freq': 2, 'docs': [ObjectId('616fcefee3381e0ff1881767')]}

# %% [markdown]
# Обратите внимание, что при обновлении заменяетя весь документ целиком. Чтобы избежать этого следует использовать ключевое слово `$set`, которое показывает, что обновляется значение только одного поля.

# %%
# Просто посмотрим на документы
for d in dictionary.find({'token':{'$regex':'^И.+'}}):
    print(d)
# Out:
# {'_id': ObjectId('616fcef5e3381e0ff1880431'), 'token': 'ИТМО', 'iniForm': 'итмый', 'POS': 'ADJS', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef8e3381e0ff1880c73'), 'token': 'Ивтушок', 'iniForm': 'ивтушок', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef6e3381e0ff18807da')]}
# {'_id': ObjectId('616fcef5e3381e0ff188046e'), 'token': 'Из', 'iniForm': 'из', 'POS': 'PREP', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcefde3381e0ff188149c'), 'token': 'Известно', 'iniForm': 'известно', 'POS': 'PRED', 'freq': 1, 'docs': [ObjectId('616fcefce3381e0ff18813a0')]}
# {'_id': ObjectId('616fcef6e3381e0ff1880720'), 'token': 'Изначально', 'iniForm': 'изначально', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881bef'), 'token': 'Изучив', 'iniForm': 'изучить', 'POS': 'GRND', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef6e3381e0ff188057e'), 'token': 'Илон', 'iniForm': 'илона', 'POS': 'NOUN', 'freq': 2, 'docs': [ObjectId('616fcef6e3381e0ff1880558')]}
# {'_id': ObjectId('616fcefce3381e0ff1881323'), 'token': 'Им', 'iniForm': 'они', 'POS': 'NPRO', 'freq': 3, 'docs': [ObjectId('616fcefce3381e0ff188130d'), ObjectId('616fcefee3381e0ff1881767'), ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcefbe3381e0ff188112e'), 'token': 'Инженеры', 'iniForm': 'инженер', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef5e3381e0ff18804e9'), 'token': 'Интенсивные', 'iniForm': 'интенсивный', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}
# {'_id': ObjectId('616fcef8e3381e0ff1880cc0'), 'token': 'Интересно', 'iniForm': 'интересно', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('616fcef8e3381e0ff1880c75')]}
# {'_id': ObjectId('616fcf00e3381e0ff1881b37'), 'token': 'Испании', 'iniForm': 'испания', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fceffe3381e0ff18819c7')]}
# {'_id': ObjectId('616fcef7e3381e0ff188081a'), 'token': 'Использование', 'iniForm': 'использование', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcef6e3381e0ff18807da')]}
# {'_id': ObjectId('616fcefbe3381e0ff1881162'), 'token': 'Испытания', 'iniForm': 'испытание', 'POS': 'NOUN', 'freq': 1, 'docs': [ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef9e3381e0ff1880deb'), 'token': 'Исследователи', 'iniForm': 'исследователь', 'POS': 'NOUN', 'freq': 3, 'docs': [ObjectId('616fcef8e3381e0ff1880c75'), ObjectId('616fcefae3381e0ff1880ee4'), ObjectId('616fcefbe3381e0ff188112d')]}
# {'_id': ObjectId('616fcef5e3381e0ff1880493'), 'token': 'Их', 'iniForm': 'они', 'POS': 'NPRO', 'freq': 1, 'docs': [ObjectId('616fcef5e3381e0ff188026b')]}

# %%
# А теперь найдем первое попавшееся слово, начинающееся с заглавное И и добавим ему новое поле found
dictionary.find_one_and_update({'token':{'$regex':'^И.+'}, 'found':'false'}, {'$set': {'found':'true'}})

# %%
for r in dictionary.find({'token': 'Изначально'}):
    print(r)
# Out:
# {'_id': ObjectId('616fcef6e3381e0ff1880720'), 'token': 'Изначально', 'iniForm': 'изначально', 'POS': 'ADVB', 'freq': 1, 'docs': [ObjectId('616fcef6e3381e0ff1880558')]}

# %% [markdown]
# Ничего не получилось, так как поле found отсутствует у всех записей. Попробуем теперь найти первую запись, у которой нет такого поля: 'found':{"$exists":False}} .

# %%
dictionary.find_one_and_update({'token':{'$regex':'^А.+'}, 'found':{"$exists":False}}, {'$set': {'found':'true'}})
# Out:
# {'_id': ObjectId('616fcefce3381e0ff1881349'),
#  'token': 'Абелевскую',
#  'iniForm': 'абелёвский',
#  'POS': 'ADJF',
#  'freq': 1,
#  'docs': [ObjectId('616fcefce3381e0ff188130d')]}

# %%
# Попробуем найти все документы с полем found.
for d in dictionary.find({'token':{'$regex':'^А.+'}, 'found':{"$exists":True}}):
    print(d)
# Out:
# {'_id': ObjectId('616fcefce3381e0ff188131d'), 'token': 'Абелевской', 'iniForm': 'абелёвский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcefce3381e0ff188130d')], 'found': 'true'}
# {'_id': ObjectId('616fcefce3381e0ff1881349'), 'token': 'Абелевскую', 'iniForm': 'абелёвский', 'POS': 'ADJF', 'freq': 1, 'docs': [ObjectId('616fcefce3381e0ff188130d')], 'found': 'true'}

# %% [markdown]
# #### Важное замечание
#
# Вся структура нашей базы данных отдает реляционностью. Никто не мешал нам сделать документ, вложенный в словарь начальных форм и хранить в нем все формы данного слова. Тогда если что, не надо будет делать запросы, в которых надо делать пересечение двух коллекций.

# %% [markdown]
# {"iniForm":"абелёвский", 'POS': 'ADJF', "forms":[{'token': 'Абелевской', "tags":"род ед муж"}, {'token': 'Абелевский', "tags":"им ед муж"}]}

# %% [markdown]
# ## Работа с географическими данными
#
# MongoDB позволяет работать с географическими данными. Основой является [GEO JSON](https://docs.mongodb.com/manual/reference/geojson/), позволяющий обрабатывать разные виды геолокаций.

# %%
text_collection.find_one_and_update(
    {'_id': ObjectId('616fcef4e3381e0ff188001c')},
    {"$set":{'coord':{ 'type': "Point", 'coordinates': [ 20, 15 ] }}})
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'),
#  'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes',
#  'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания',
#  'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к Красной планете этим летом, успешно прошел заключительные термовакуумные испытания, имитировавшие\xa0условия марсианской среды, в которых предстоит работать роверу,\xa0сообщается на сайте ESA.Старт второго этапа российско-европейской программы «ЭкзоМарс» намечен на период с 26 июля по 11 августа 2020 года. Ракета-носитель «Протон» выведет в космос перелетный модуль, который доставит к Марсу десантный модуль, содержащий в себе автономную научную станцию «Казачок»\xa0и марсоход «Розалинд Франклин». Посадка на поверхность Красной планеты должна состояться 19 марта 2021 года, в качестве места работы аппаратов выбрана\xa0равнина Оксия в северном полушарии Марса, где есть сухие русла. Задачей марсохода будет\xa0поиск соединений и веществ, которые могли бы свидетельствовать о возможном существовании на планете жизни в прошлом, а также изучение геологии Марса. Научная станция займется исследованием\xa0состава и свойств поверхности и атмосферы Красной планеты.В конце августа 2018 года была завершена сборка марсохода, после чего его отправили в цеха компании\xa0Airbus в Тулузе для прохождения заключительных термических и вакуумных испытаний, имитирующих условия марсианской среды. Аппарат должен функционировать\xa0при атмосферном давлении, значение которого составляет менее одной сотой от земного, и низких температурах. Моделирование показывает, что при температуре окружающего воздуха\xa0–120 градусов по Цельсию, температура внутри ровера составит –50 градусов по Цельсию.\xa0В конце 2019 года испытательная программа была успешно завершена, в настоящее время ведется заключительное тестирование всех систем марсохода. После его окончания ровер будет перевезен в компанию\xa0Thales Alenia Space в Каннах, где будет проведена проверка его совместимости с посадочной платформой и десантным модулем.Ранее мы рассказывали о трудностях, с которыми пришлось столкнуться специалистам при разработке тормозной системы для\xa0«ЭкзоМарса-2020».Александр Войтюк\n                            \n                            \n                                                \n                        \n                                            ',
#  'art_info': {'art_date': '20 Янв. 2020',
#   'art_time': '14:18',
#   'difficulty': '2.3',
#   'author': 'Александр Войтюк'},
#  'coord': {'type': 'Point', 'coordinates': [20, 15]}}

# %%
for a in text_collection.find():
    print(a)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'), 'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes', 'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания', 'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к Красной планете этим летом, успешно прошел заключительные термовакуумные испытания, имитировавшие\xa0условия марсианской среды, в которых предстоит работать роверу,\xa0сообщается на сайте ESA.Старт второго этапа российско-европейской программы «ЭкзоМарс» намечен на период с 26 июля по 11 август
удалось создать предсказанный два года назад резонатор. Ученые добились времени захвата света на\xa0порядок выше, чем в\xa0предыдущих работах. \n«Из\xa0арсенида галлия были изготовлены цилиндры высотой около 700\xa0нм с\xa0различными диаметрами, близкими к\xa0900\xa0нм. Их\xa0практически не\xa0увидеть невооруженным взглядом. Как показал эксперимент, эталонная частица захватила свет на\xa0время, превышающее в\xa0200 раз период одного колебания световой волны. Обычно для частицы таких размеров этот показатель не\xa0превышает 5\xa0— 10\xa0периодов световых колебаний. А\xa0здесь 200!»,\xa0— говорит Кирилл Кошелев.\nИнтенсивные импульсы света, взаимодействующие с\xa0диэлектриком, могут стать причиной оптически нелинейного отклика среды, в\xa0результате чего частота выходной электромагнитной волны может быть увеличена в\xa0несколько раз (следовательно, цвет света, прошедшего через такую среду изменится в\xa0сторону фиолетового). Проблема в\xa0том, что этот процесс довольно слаб и\xa0происходит на\xa0расстояниях порядка тысячи длин волн. \n\n    \n        \n                        \n                \n                    \n                        \n                    ', 'art_info': {'art_date': '20 Янв. 2020', 'art_time': '10:40', 'difficulty': '4.2', 'author': 'Олег Макаров'}}
# {'_id': ObjectId('616fcef6e3381e0ff1880558'), 'text_url': 'https://nplus1.ru/news/2020/01/20/crew-dragon-first-crewed-flight', 'text_name': 'Пилотируемый полет Crew Dragon к МКС состоится в первой половине 2020 года', 'art_text': 'Первый пилотируемый полет космического корабля Crew Dragon, вероятнее всего, пройдет во\xa0втором квартале 2020\xa0года, заявил глава SpaceX Илон Маск. При этом технически корабль и\xa0ракета будут готовы к\xa0запуску уже в\xa0феврале или марте, сообщает Space.com со\xa0ссылкой на\xa0пресс-конференцию после успешного испытания системы аварийного спасения корабля в\xa0полете.\nВ\xa02011 году NASA прекратило использовать пилотируемые космические корабли Space Shuttle и доставка астронавтов на\xa0МКС перешла к\xa0российским «Союзам». Для того, чтобы астронавты вновь могли летать на американских кораблях, NASA утвердило конкурс по\xa0разработке частных пилотируемых кораблей.\xa0До\xa0финального этапа дошли SpaceX и\xa0Boeing, которые на\xa0протяжении нескольких лет разрабатывали свои корабли Crew Dragon и\xa0CST-100\xa0Starliner. В\xa02019 году обе компании отправили свои аппараты в\xa0космос (Boeing столкнулась с\xa0проблемами, Starliner вернулся на\xa0Землю, не\xa0достигнув МКС), а\xa0на\xa02020 год оба разработчика наметили первый тестовый пилотируемый полет, после которого должна начаться эксплуатация.\nИлон Маск заявил, что первая пилотируемая миссия (Demo-2) состоится скорее всего во\xa0втором квартале 2020\xa0года, а\xa0технически корабль будет готов к\xa0отправке в\xa0марте. За\xa0несколько дней до\xa0этого NASA заявило, что Demo-2 может состояться уже в\xa0марте, поэтому можно предположить, что Маск назвал сроки с\xa0учетом возможных задержек.\nОдной из\xa0причин сдвига сроков полета может стать\xa0то, что после неудачных испытаний парашютов Crew Dragon в\xa0мае 2019 года NASA требует от\xa0SpaceX провести еще два испытания парашютов. Пока они намечены на\xa0середину февраля, но\xa0даже при успешном исходе специалистам понадобится время на\xa0анализ данных.\nNASA объявило состав экипажа первой пил
ент немного отличался от первого: вознаграждение давали только один раз — во время изначального обучения, но не повторения (разумеется, только в тех группах, которым вознаграждение полагалось — так же, как и в первом эксперименте). Таким образом ученые исключили влияние вознаграждения на результаты во время выполнения задания, так как использовалось оно только в процессе изначального обучения. Результаты оказались такими же: правильных ответов стало на 25 процентов больше в группе, которая получала вознаграждение во время обучения перед сном. Для сравнения, без вознаграждения результаты улучшились только на 15 процентов, а в утренней группе и вовсе стали хуже.В третьем эксперименте участвовали уже две группы, эксперимент проходил в дневное время, а продолжительность сна сократили до двух часов. Ученые предположили, что на улучшение обучения во время сна может влиять время нахождения в каждой его фаза, а определять его — активность мозга в определенных диапазонах. Для того, чтобы проверить это, к участникам во время сна подключили полисомнографы.\xa0Вознаграждение и сон после опять улучшили результаты: на 38 процентов по сравнению с улучшением в 20 процент ...
# {'_id': ObjectId('616fcef8e3381e0ff1880c75'), 'text_url': 'https://nplus1.ru/news/2020/01/18/dancing-recognition', 'text_name': 'Машинное обучение помогло распознать человека по танцу', 'art_text': 'Финские ученые выяснили, что по движениям во время свободного танца можно автоматически определить танцующего с точностью выше 90 процентов. Для этого они обучили классификатор, основанный на методе опорных векторов, и использовали для этого движения 73 человек, танцующих под 16 песен разных жанров. Интересно, что жанр песни по танцу классификатор определить не смог. Статья опубликована в Journal of New Music Research.\xa0Танец в первую очередь предполагает ритмичные движения, подходящие под исполняемую музыку: например, очевидно, что под музыку с высоким темпом человек будет танцевать более энергично. Подобная связь, разумеется, двусторонняя: точно так же, как музыка предполагает определенный танец, танец должен подходить под музыку. Получается, по исполняемым во время танца движениям можно определить изначальную музыку.\xa0Ученые под руководством Эмили Карлсон (Emily Carlson) из\xa0Университет Йювяскюля\xa0решили попробовать сделать это автоматически. Для этого они попросили 73 добровольцев потанцевать под 16 композиций восьми разных жанров: в список вошли, например, песня «Want You More!» группы Duran Duran и джазовая композиция «Muskrat Ramble» в исполнении Сиднея Беше. Движения участников во время танца регистрировали с помощью системы захвата движений, на основе чего создавалась движущаяся двухмерная модель их тела.Полученные данные ученые классифицировали с помощью алгоритма, основанного на методе опорных векторов. Такой метод позволяет расположить объекты в многомерном пространстве в зависимости от того, как они отличаются друг от друга по тем или иным признакам, которые выделяются из данных: например, в случае с танцем это могла быть скорость движения головы.Исследователи попробовали классифицировать модели движений по двум признакам: жанру и тому, кто его танцует. С определением жанра алгоритм справился плохо: в среднем его точность была менее 30 процентов. А вот отдельного участника исследования по танцу он определил с очень высокой точностью — около 94 процентов. Самыми значимыми признаками, по которым алгоритм классифицировал танцы, оказались движения головы, плеч и коленей.\n    \n        \n                        \n                \n                    \n                        \n                    ', 'art_info': {'art_date': '18 Янв. 2020', 'art_time': '18:02', 'difficulty': '1.9', 'author': 'Елизавета Ивтушок'}}
n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '12 Апр. 2016', 'art_time': '15:26', 'difficulty': '3.3', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('616fcefbe3381e0ff18810a6'), 'text_url': 'https://nplus1.ru/news/2016/06/29/Ultra-Deep-Survey', 'text_name': 'Астрономы провели самый глубокий обзор Вселенной', 'art_text': 'Астрономы опубликовали новые изображения далекой Вселенной. Это самые «глубокие» фотографии такой обширной части неба. Результаты работы ученых были представлены на\xa0Национальном астрономическом собрании в\xa0Университете Ноттингема.\nОкончательные данные обзора Ultra-Deep Survey (UDS) показывают карту области неба, в\xa0четыре раза превышающую размер полной Луны (0,8 квадратных градусов). Фотографии были сделаны в\xa0ближнем инфракрасном и\xa0оптическом диапазоне с\xa0помощью телескопов\xa0United Kingdom Infra-Red Telescope и\xa0Subaru (предельные доступные звёздные величины в данных фильтрах J = 25,6, H = 25,1, K = 25,3 ). Ученые наблюдали один и\xa0тот\xa0же участок неба несколько раз, в\xa0сумме накопив более 1\xa0тысячи часов экспозиции.\n\n    \n        \n                        \n                \n                    \n                        \n                    ', 'art_info': {'art_date': '29 Июнь 2016', 'art_time': '14:51', 'difficulty': '4.7', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('616fcefbe3381e0ff188112d'), 'text_url': 'https://nplus1.ru/news/2018/03/20/balance', 'text_name': 'Вентиляторы в ногах помогли роботу перешагнуть пропасть', 'art_text': 'Инженеры создали робота с вентиляторными движителями в стопах для преодоления больших препятствий. При широком шаге вентилятор компенсирует вес ноги и позволяет роботу удерживать равновесие. Испытания показали, что робот может преодолевать препятствия длиной до 80\xa0процентов длины ноги, сообщается в\xa0работе, о\xa0которой рассказывает IEEE Spectrum.Шагающие роботы способны преодолевать небольшие препятствия и двигаться по неровным поверхностям, но чтобы сохранить равновесие, им приходится сокращать длину шага. Дело в том, что при большом отклонении ноги роботу сложно удерживать равновесие из-за сильного смещения центра тяжести. Для решения этой проблемы предлагаются разные способы, например, активная компенсация изменения центра тяжести с движениями руками и телом, но это сильно усложняет конструкцию робота и алгоритмы его управления.Инженеры под руководством Юня Чжана (Yun Zhang) из Гуандунского технологического университета предложили использовать для компенсации смещения центра тяжести при больших шагах вентиляторы. Для проверки концепции разработчики создали двуногого робота\xa0Jet-HR1 высотой 65 сантиметров и длиной ног 46 сантиметров. В нижнем сегменте каждой ноги установлен вентилятор с кольцевым обтекателем. Он может выдавать тягу в два килограмма при том, что общий вес робота составляет 6,5 килограммов.Инженеры разработали алгоритм балансировки робота с помощью вентиляторов. Поскольку скорость движения всех частей ног довольно мала, исследователи пренебрегли ей и принимали в расчет только силу притяжения и тягу вентиляторов. Во время движения ноги робот постоянно подстраивает тягу двигателя для удержания ноги. После того, как передняя нога оказывается на нужном месте, робот подтягивает вторую ногу таким же образом. Исследователи показали, как робот может перешагивать через большие препятствия с длиной до 80 процентов от длины ноги:Некоторые продвинутые роботы могут удерживать баланс и без таких приспособлений. Например, в 2016 году Boston Dynamics показала испытания гуманоидного робота Atlas, во время которых он стоял на одной ноге, поддерживая равновесия движениями рук и корпуса подобно людям.Григорий Копиев\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date':
годы у\xa0берегов Норвегии и\xa0в\xa0Средиземном море (несколько сфер также были обнаружены в\xa0водах Швеции, у\xa0северного побережья Испании и\xa0восточного побережья Великобритании).Все встречи со\xa0сферами происходили с\xa0марта по\xa0октябрь, причем в\xa0Норвегии пик наблюдений приходился на\xa0июль-август, а\xa0в\xa0Средиземном море\xa0— на\xa0август-сентябрь. На\xa0севере загадочные объекты в\xa0основном дрейфовали на\xa0глубинах до\xa0двадцати метров, а\xa0на\xa0юге встречались до\xa030-50 метров ниже уровня моря. Размер сфер довольно сильно варьировался. Рингвольд с\xa0соавторами разделили их\xa0на\xa0три класса: диаметром менее полуметра, от\xa0полуметра до\xa0метра и\xa0более метра. Ко\xa0второй группе относилось более половины сфер (58\xa0процентов). При этом у\xa055\xa0процентов объектов через центр проходила некая структура, напоминающая темную полосу.Благодаря помощи дайверов Рингвольд и\xa0ее\xa0соавторам удалось получить образцы четырех сфер диаметром от\xa0полутора метров до\xa0метра, обнаруженных у\xa0берегов Норвегии летом 2019\xa0года. Изучив\xa0их, специалисты пришли к\xa0выводу, что это действительно яйца кальмаров длиной один-два миллиметра в\xa0студенистой оболочке.Анализ ДНК позволил точно определить вид, которому они принадлежат. Им\xa0оказался кальмар Illex coindetii из\xa0семейства Ommastrephidae, широко распространенный в\xa0Северной Атлантике, в\xa0том числе в\xa0Средиземном море. Несмотря на\xa0то, что этих головоногих впервые описали еще в\xa0середине XIX\xa0века, до\xa0сих пор оставалось неизвестным, как именно выглядят их\xa0яйца. Впрочем, авторы допускают, что сферы диаметром более метра принадлежат более крупному виду кальмаров из\xa0того\xa0же семейства, например, Todarodes sagittatus или Todaropsis eblanae. К\xa0сожалению, образцов самых больших сфер они получить не\xa0смогли.Благодаря наблюдениям в\xa0неволе за\xa0другими представителями рода Illex биологи знают, что студенистая оболочка, внутри которой могут содержаться до\xa0нескольких сотен тысяч яиц, производится специальными железами в\xa0мантийной полости самок. Сферы не дают яйцам опуститься на\xa0дно, так что те остаются в слое воды, где температура оптимал ...

# %%
for d in text_collection.find({'coord':{'$geoIntersects':{"$geometry": 
{"type": "Polygon",
 "coordinates": [[[15,10], [15,20],[25,20], [25,10], [15,10]]]
}}}}):
    print(d)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'), 'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes', 'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания', 'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к Красной планете этим летом, успешно прошел заключительные термовакуумные испытания, имитировавшие\xa0условия марсианской среды, в которых предстоит работать роверу,\xa0сообщается на сайте ESA.Старт второго этапа российско-европейской программы «ЭкзоМарс» намечен на период с 26 июля по 11 августа 2020 года. Ракета-носитель «Протон» выведет в космос перелетный модуль, который доставит к Марсу десантный модуль, содержащий в себе автономную научную станцию «Казачок»\xa0и марсоход «Розалинд Франклин». Посадка на поверхность Красной планеты должна состояться 19 марта 2021 года, в качестве места работы аппаратов выбрана\xa0равнина Оксия в северном полушарии Марса, где есть сухие русла. Задачей марсохода будет\xa0поиск соединений и веществ, которые могли бы свидетельствовать о возможном существовании на планете жизни в прошлом, а также изучение геологии Марса. Научная станция займется исследованием\xa0состава и свойств поверхности и атмосферы Красной планеты.В конце августа 2018 года была завершена сборка марсохода, после чего его отправили в цеха компании\xa0Airbus в Тулузе для прохождения заключительных термических и вакуумных испытаний, имитирующих условия марсианской среды. Аппарат должен функционировать\xa0при атмосферном давлении, значение которого составляет менее одной сотой от земного, и низких температурах. Моделирование показывает, что при температуре окружающего воздуха\xa0–120 градусов по Цельсию, температура внутри ровера составит –50 градусов по Цельсию.\xa0В конце 2019 года испытательная программа была успешно завершена, в настоящее время ведется заключительное тестирование всех систем марсохода. После его окончания ровер будет перевезен в компанию\xa0Thales Alenia Space в Каннах, где будет проведена проверка его совместимости с посадочной платформой и десантным модулем.Ранее мы рассказывали о трудностях, с которыми пришлось столкнуться специалистам при разработке тормозной системы для\xa0«ЭкзоМарса-2020».Александр Войтюк\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '20 Янв. 2020', 'art_time': '14:18', 'difficulty': '2.3', 'author': 'Александр Войтюк'}, 'coord': {'type': 'Point', 'coordinates': [20, 15]}}

# %% [markdown]
# #### Важное замечание
#
# !!! Если не построить этот индекс, то искаться не будет!!!

# %%
#lemmas.create_index([('iniForm', pymongo.ASCENDING), ('POS', pymongo.ASCENDING)], unique=True)

text_collection.create_index([("coord", pymongo.GEOSPHERE)], unique=False)
# Out:
# 'coord_2dsphere'

# %%
req=text_collection.find(
{
   "coord": {
     "$near": {
       "$geometry": {
          "type": "Point" ,
          "coordinates": [ 19.999 , 15.001 ]
       },
       "$maxDistance": 1000,
       "$minDistance": 0
     }
   }
}
)
#req
for d in req:    
    print(d)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'), 'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes', 'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания', 'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к Красной планете этим летом, успешно прошел заключительные термовакуумные испытания, имитировавшие\xa0условия марсианской среды, в которых предстоит работать роверу,\xa0сообщается на сайте ESA.Старт второго этапа российско-европейской программы «ЭкзоМарс» намечен на период с 26 июля по 11 августа 2020 года. Ракета-носитель «Протон» выведет в космос перелетный модуль, который доставит к Марсу десантный модуль, содержащий в себе автономную научную станцию «Казачок»\xa0и марсоход «Розалинд Франклин». Посадка на поверхность Красной планеты должна состояться 19 марта 2021 года, в качестве места работы аппаратов выбрана\xa0равнина Оксия в северном полушарии Марса, где есть сухие русла. Задачей марсохода будет\xa0поиск соединений и веществ, которые могли бы свидетельствовать о возможном существовании на планете жизни в прошлом, а также изучение геологии Марса. Научная станция займется исследованием\xa0состава и свойств поверхности и атмосферы Красной планеты.В конце августа 2018 года была завершена сборка марсохода, после чего его отправили в цеха компании\xa0Airbus в Тулузе для прохождения заключительных термических и вакуумных испытаний, имитирующих условия марсианской среды. Аппарат должен функционировать\xa0при атмосферном давлении, значение которого составляет менее одной сотой от земного, и низких температурах. Моделирование показывает, что при температуре окружающего воздуха\xa0–120 градусов по Цельсию, температура внутри ровера составит –50 градусов по Цельсию.\xa0В конце 2019 года испытательная программа была успешно завершена, в настоящее время ведется заключительное тестирование всех систем марсохода. После его окончания ровер будет перевезен в компанию\xa0Thales Alenia Space в Каннах, где будет проведена проверка его совместимости с посадочной платформой и десантным модулем.Ранее мы рассказывали о трудностях, с которыми пришлось столкнуться специалистам при разработке тормозной системы для\xa0«ЭкзоМарса-2020».Александр Войтюк\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '20 Янв. 2020', 'art_time': '14:18', 'difficulty': '2.3', 'author': 'Александр Войтюк'}, 'coord': {'type': 'Point', 'coordinates': [20, 15]}}

# %%
for d in text_collection.find({'coord':{'$geoWithin':{"$box": 
[[15,10], [25,20]]
}}}):
    print(d)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'), 'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes', 'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания', 'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к Красной планете этим летом, успешно прошел заключительные термовакуумные испытания, имитировавшие\xa0условия марсианской среды, в которых предстоит работать роверу,\xa0сообщается на сайте ESA.Старт второго этапа российско-европейской программы «ЭкзоМарс» намечен на период с 26 июля по 11 августа 2020 года. Ракета-носитель «Протон» выведет в космос перелетный модуль, который доставит к Марсу десантный модуль, содержащий в себе автономную научную станцию «Казачок»\xa0и марсоход «Розалинд Франклин». Посадка на поверхность Красной планеты должна состояться 19 марта 2021 года, в качестве места работы аппаратов выбрана\xa0равнина Оксия в северном полушарии Марса, где есть сухие русла. Задачей марсохода будет\xa0поиск соединений и веществ, которые могли бы свидетельствовать о возможном существовании на планете жизни в прошлом, а также изучение геологии Марса. Научная станция займется исследованием\xa0состава и свойств поверхности и атмосферы Красной планеты.В конце августа 2018 года была завершена сборка марсохода, после чего его отправили в цеха компании\xa0Airbus в Тулузе для прохождения заключительных термических и вакуумных испытаний, имитирующих условия марсианской среды. Аппарат должен функционировать\xa0при атмосферном давлении, значение которого составляет менее одной сотой от земного, и низких температурах. Моделирование показывает, что при температуре окружающего воздуха\xa0–120 градусов по Цельсию, температура внутри ровера составит –50 градусов по Цельсию.\xa0В конце 2019 года испытательная программа была успешно завершена, в настоящее время ведется заключительное тестирование всех систем марсохода. После его окончания ровер будет перевезен в компанию\xa0Thales Alenia Space в Каннах, где будет проведена проверка его совместимости с посадочной платформой и десантным модулем.Ранее мы рассказывали о трудностях, с которыми пришлось столкнуться специалистам при разработке тормозной системы для\xa0«ЭкзоМарса-2020».Александр Войтюк\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '20 Янв. 2020', 'art_time': '14:18', 'difficulty': '2.3', 'author': 'Александр Войтюк'}, 'coord': {'type': 'Point', 'coordinates': [20, 15]}}

# %%
#text_collection.create_index([('text_name', pymongo.ASCENDING)], unique=False)
text_collection.create_index([('art_text', pymongo.TEXT)], unique=False)
# Out:
# 'art_text_text'

# %%
#for d in text_collection.find({'text_name': 'Бактерии помогли получить катализатор для электролиза воды'}):
# for d in text_collection.find({
#   "$text":{"$search": "воды"}}):
        
#for d in text_collection.find({'art_text':{'$regex':'воды'}}):
for d in text_collection.find({ "$text": { "$search": "Американское учеными" } } ):
# for d in text_collection.find({ "$text": { "$search": "Американ" } } ):
    print(d)

# %%
for d in text_collection.find():
    print(d)
# Out:
# {'_id': ObjectId('616fcef4e3381e0ff188001c'), 'text_url': 'https://nplus1.ru/news/2020/01/20/Exomars-2020-rover-yes', 'text_name': 'Марсоход миссии «ЭкзоМарс-2020» прошел термовакуумные испытания', 'art_text': 'Марсоход «Розалинд Франклин», который должен отправиться к Красной планете этим летом, успешно прошел заключительные термовакуумные испытания, имитировавшие\xa0условия марсианской среды, в которых предстоит работать роверу,\xa0сообщается на сайте ESA.Старт второго этапа российско-европейской программы «ЭкзоМарс» намечен на период с 26 июля по 11 августа 2020 года. Ракета-носитель «Протон» выведет в космос перелетный модуль, который доставит к Марсу десантный модуль, содержащий в себе автономную научную станцию «Казачок»\xa0и марсоход «Розалинд Франклин». Посадка на поверхность Красной планеты должна состояться 19 марта 2021 года, в качестве места работы аппаратов выбрана\xa0равнина Оксия в северном полушарии Марса, где есть сухие русла. Задачей марсохода будет\xa0поиск соединений и веществ, которые могли бы свидетельствовать о возможном существовании на планете жизни в прошлом, а также изучение геологии Марса. Научная станция займется исследованием\xa0состава и свойств поверхности и атмосферы Красной планеты.В конце августа 2018 года была завершена сборка марсохода, после чего его отправили в цеха компании\xa0Airbus в Тулузе для прохождения заключительных термических и вакуумных испытаний, имитирующих условия марсианской среды. Аппарат должен функционировать\xa0при атмосферном давлении, значение которого составляет менее одной сотой от земного, и низких температурах. Моделирование показывает, что при температуре окружающего воздуха\xa0–120 градусов по Цельсию, температура внутри ровера составит –50 градусов по Цельсию.\xa0В конце 2019 года испытательная программа была успешно завершена, в настоящее время ведется заключительное тестирование всех систем марсохода. После его окончания ровер будет перевезен в компанию\xa0Thales Alenia Space в Каннах, где будет проведена проверка его совместимости с посадочной платформой и десантным модулем.Ранее мы рассказывали о трудностях, с которыми пришлось столкнуться специалистам при разработке тормозной системы для\xa0«ЭкзоМарса-2020».Александр Войтюк\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '20 Янв. 2020', 'art_time': '14:18', 'difficulty': '2.3', 'author': 'Александр Войтюк'}, 'coord': {'type': 'Point', 'coordinates': [20, 15]}}
# {'_id': ObjectId('616fcef5e3381e0ff188026b'), 'text_url': 'https://nplus1.ru/news/2020/01/20/subwavelength-resonators', 'text_name': 'Физики заперли свет в нанорезонаторе на рекордно долгое время', 'art_text': '\nФизики создали резонатор размером в несколько сотен нанометров, способный удерживать свет внутри себя на\xa0время, за\xa0которое световая волна совершает более 200 периодов колебаний. На\xa0основе него ученые создали устройство, которое увеличивает частоту входного света в\xa0два раза, а в будущем такие нанорезонаторы могут стать основой для создания оптических средств связи, приборов ночного видения и\xa0компактных сенсоров. Работа опубликована в\xa0журнале Science. \nС\xa0помощью электрооптики можно передавать информацию
е опорных векторов. Такой метод позволяет расположить объекты в многомерном пространстве в зависимости от того, как они отличаются друг от друга по тем или иным признакам, которые выделяются из данных: например, в случае с танцем это могла быть скорость движения головы.Исследователи попробовали классифицировать модели движений по двум признакам: жанру и тому, кто его танцует. С определением жанра алгоритм справился плохо: в среднем его точность была менее 30 процентов. А вот отдельного участника исследования по танцу он определил с очень высокой точностью — около 94 процентов. Самыми значимыми признаками, по которым алгоритм классифицировал танцы, оказались движения головы, плеч и коленей.\n    \n        \n                        \n                \n                    \n                        \n                    ', 'art_info': {'art_date': '18 Янв. 2020', 'art_time': '18:02', 'difficulty': '1.9', 'author': 'Елизавета Ивтушок'}}
# {'_id': ObjectId('616fcef9e3381e0ff1880e4b'), 'text_url': 'https://nplus1.ru/news/2016/06/27/juno-pictures', 'text_name': 'Астрономы провели разведку для «Юноны»', 'art_text': 'Астрономы получили новые фотографии Юпитера в\xa0инфракрасном диапазоне. Снимки были представлены на\xa0Национальном астрономическом съезде Британского Королевского астрономического общества в\xa0Ноттингеме и\xa0размещены на\xa0сайте Европейской южной обсерватории.\nГруппа исследователей под руководством Ли\xa0Флетчера (Leigh Fletcher) из\xa0Лестерского университета в\xa0Великобритании представила снимки, которые были получены с\xa0помощью спектрометра и\xa0отображателя в\xa0инфракрасном диапазоне VISIR, установленного на\xa0Very Large Telescope. Эти фотографии были сделаны в\xa0рамках кампании по\xa0исследованию атмосферы Юпитера перед прибытием к\xa0газовому гиганту автоматической межпланетной станции NASA «Юнона».\n\n    \n        \n                        \n                \n                    \n                        \n                    ', 'art_info': {'art_date': '27 Июнь 2016', 'art_time': '13:12', 'difficulty': '2.7', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('616fcefae3381e0ff1880ee4'), 'text_url': 'https://nplus1.ru/news/2016/04/12/alignment-of-jets', 'text_name': 'Астрономы внезапно нашли сонаправленные джеты', 'art_text': 'Астрономы из\xa0Кейптаунского Университета и\xa0Университета Западно-Капской провинции в\xa0Южной Африке обнаружили массивные черные дыры, джеты которых ориентированы в\xa0одном направлении. Подобное явление на больших масштабах было замечено учеными впервые и не было \nпредсказано существующими теориями, поэтому в будущем его только \nпредстоит изучить. Работа авторов опубликована в\xa0журнале Monthly Notices of\xa0the Royal Astronomical Society, также она доступна на\xa0сайте ArXiv.org.\nИсследователи вели наблюдения в течение трех лет в\xa0радиоволновом диапазоне при помощи телескопа Giant Metrewave Radio Telescope (GMRT) за\xa0участком неба ELAIS N1. Первоначальной задачей глубокого обзора было изучение самых слабых радиоисточников во\xa0Вселенной. Упорядоченно ориентированные джеты астрономы обнаружили случайно, после того, как получили конечное изображение 65 джетов. Часть джетов, как видно на изображении выше, сонаправлены. Обязательным условием такой закономерности, как замечает один из\xa0авторов исследования, является вращение черных дыр (которыми и\xa0производятся эти джеты) в\xa0одном направлении. «Так как эти черные дыры ничего друг о\xa0друге не\xa0знают и\xa0не\xa0могут обмениваться информацией или влиять друг на\xa0друга в таком большом масштабе, то, скорее всего, эта ориентированность осей вращения могла появиться во\xa0времена формирования галактик на\xa0раннем этапе эволюции Вселенной»\xa0— замечает профессор Расс Тэйлор (Russ Taylor), ведущий автор исследования.В качестве наиболее вероятной причины сонаправленности релятивистских струй ученые указывают первичные флуктуации массы в ранней Вселенной. Кроме того, в качестве возможных факторов, повлиявших на ориентацию джетов, исследователи называют, например, космические магнитные поля и космические струны.Ранее астрофизики получили изображение джета,\n исходящего из черной дыры в центре галактики Pictor A, который по своей\n длине оказался в три раза больше диаметра Млечного пути. Также им \nудалось получить изображение джета, исходящего в обратном направлении \n(counterjet).Кристина Уласович\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '12 Апр. 2016', 'art_time': '15:26', 'difficulty': '3.3', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('616fcefbe3381e0ff18810a6'), 'text_url': 'https://nplus1.ru/news/2016/06/29/Ultra-Deep-Survey', 'text_name': 'Астрономы провели самый глубокий обзор Вселенной', 'art_text': 'Астрономы опубликовали новые изображения далекой Вселенной. Это самые «глубокие» фотографии такой обширной части неба. Результаты работы ученых были представлены на\xa0Национальном астрономическом собрании в\xa0Университете Ноттингема.\nОкончательные данные обзора Ultra-Deep Survey (UDS) показывают карту области неба, в\xa0четыре раза превышающую размер полной Луны (0,8 квадратных градусов). Фотографии были сделаны в\xa0ближнем инфракрасном и\xa0оптическом диапазоне с\xa0помощью телескопов\xa0United Kingdom Infra-Red Telescope и\xa0Subaru (предельные доступные звёздные величины в данных фильтрах J = 25,6, H = 25,1, K = 25,3 ). Ученые наблюдали один и\xa0тот\xa0же участок неба несколько раз, в\xa0сумме накопив более 1\xa0тысячи часов экспозиции.\n\n    \n        \n                        \n                \n                    \n                        \n                    ', 'art_info': {'art_date': '29 Июнь 2016', 'art_time': '14:51', 'difficulty': '4.7', 'author': 'Кристина Уласович'}}
# {'_id': ObjectId('616fcefbe3381e0ff188112d'), 'text_url': 'https://nplus1.ru/news/2018/03/20/balance', 'text_name': 'Вентиляторы в ногах помогли роботу перешагнуть пропасть', 'art_text': 'Инженеры создали робота с вентиляторными движителями в стопах для преодоления больших препятствий. При широком шаге вентилятор компенсирует вес ноги и позволяет роботу удерживать равновесие. Испытания показали, что робот может преодолевать препятствия длиной до 80\xa0процентов длины ноги, сообщается в\xa0работе, о\xa0которой рассказывает IEEE Spectrum.Шагающие роботы способны преодолевать небольшие препятствия и двигаться по неровным поверхностям, но чтобы сохранить равновесие, им приходится сокращать длину шага. Дело в том, что при большом отклонении ноги роботу сложно удерживать равновесие из-за сильного смещения центра тяжести. Для решения этой проблемы предлагаются разные способы, например, активная компенсация изменения центра тяжести с движениями руками и телом, но это сильно усложняет конструкцию робота и алгоритмы его управления.Инженеры под руководством Юня Чжана (Yun Zhang) из Гуандунского технологического университета предложили использовать для компенсации смещения центра тяжести при больших шагах вентиляторы. Для проверки концепции разработчики создали двуногого робота\xa0Jet-HR1 высотой 65 сантиметров и длиной ног 46 сантиметров. В нижнем сегменте каждой ноги установлен вентилятор с кольцевым обтекателем. Он может выдавать тягу в два килограмма при том, что общий вес робота составляет 6,5 килограммов.Инженеры разработали алгоритм балансировки робота с помощью вентиляторов. Поскольку скорость движения всех частей ног довольно мала, исследователи пренебрегли ей и принимали в расчет только силу притяжения и тягу вентиляторов. Во время движения ноги робот постоянно подстраивает тягу двигателя для удержания ноги. После того, как передняя нога оказывается на нужном месте, робот подтягивает вторую ногу таким же образом. Исследователи показали, как робот может перешагивать через большие препятствия с длиной до 80 процентов от длины ноги:Некоторые продвинутые роботы могут удерживать баланс и без таких приспособлений. Например, в 2016 году Boston Dynamics показала испытания гуманоидного робота Atlas, во время которых он стоял на одной ноге, поддерживая равновесия движениями рук и корпуса подобно людям.Григорий Копиев\n                            \n                            \n                                                \n                        \n                                            ', 'art_info': {'art_date': '20 Март 2018', 'art_time': '13:36', 'difficulty': '2.3', 'author': 'Григорий Копиев'}}
# {'_id': ObjectId('616fcefce3381e0ff188130d'), 'text_url': 'https://nplus1.ru/news/2018/03/20/abel-prize-2018', 'text_name': 'Абелевская премия присуждена за открытие связи между теорией чисел и теорией представлений', 'art_text': 'Норвежская академия наук объявила лауреата Абелевской премии 2018 года. Им стал канадский математик\xa0Роберт Ленглендс. Премия присуждена «за дальновидную программу, соединяющую теорию представлений и теорию чисел».\xa0Абелевскую премию часто называют «Нобелевской премией по математике». В отличие от, например, Филдсовской медали она вручается каждый год. Размер премии — 6 миллионов крон (около 45 миллионов рублей). Церемония награждения пройдет 22 мая 2018 года в Университете Аула, Осло. Вручать награду будет лично король Норвегии Харальд V.\n    \n        \n                        \n                \n                    \n                        \n                    ', 'art_info': {'art_date': '20 Март 2018', 'art_time': '14:15', 'difficulty': '6.8', 'author': 'Владимир Королев'}}
# {'_id': ObjectId('616fcefce3381e0ff18813a0'), 'text_url': 'https://nplus1.ru/news/2020/10/12/srb-electrode', 'text_name': 'Бактерии помогли получить катализатор для электролиза воды', 'art_text': 'Китайские\nхимики получили электроды для электролиза\nводы с\xa0помощью сульфатредуцирующих\nбактерий. Бактерии покрывают поверхность\nэлектрода сульфидом железа, который\nзатем облегчает адсорбцию кислород-содержащих\nчастиц. Полученные электроды показывают\nнизкое значение анодного перенапряжение\nв\xa0220\xa0милливольт, а\xa0сам процесс их\xa0получения\nочень прост — его можно будет легко\nадаптировать для промышленности.\nРезультаты исследования опубликованы\nв\xa0журнале Nature\nCommunications.Один\nиз\xa0наиболее\nэкологичных способов получения\nводородного топлива\xa0— электролиз воды.\nЧтобы\nтратить на\xa0этот процесс меньше энергии,\nученые покрывают поверхность электродов\nразными катализаторами. Для анода (на\nнем при электролизе выделяется кислород)\nочень эффективными оказались\nжелезно-никелевые катализаторы, которые\nдополнительно модифицируют\nразными\nанионными\nчастицами: гидроксильными и\xa0сульфидными.\nМатериалы\nдля таких катализаторов стоят дешево,\nно\xa0процесс их\xa0синтеза пока что достаточно\nсложен:\nученые используют методы\nгидротермального нанесения\nи\xa0электроосаждения.Китайские\nхимики под\nруководством Бао\nЮй\xa0Ся\n(Bao\nYu\xa0Xia) из\nХуачжунского университета наук и технологий попробовали модифицировать\nповерхность