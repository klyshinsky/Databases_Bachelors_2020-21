# %% [markdown]
# Мы будем работать с Postgres, так что надо проинсталлировать библиотеку для работы с ним.

# %%
#!sudo apt install libpq5=13.4-0ubuntu0.21.04.1
#!sudo apt install libpq-dev
# !pip3 install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in /home/edward/.local/lib/python3.9/site-packages (2.9.1)

# %%
# Подключаем библиотеки.
import psycopg2

from lxml import html
import requests

# %% [markdown]
# Сперва надо создать соединение с сервером, не забыв указать где находится сервер, с какой базой данных мы собираемся работать, логин и пароль для пользователя.

# %%
con = psycopg2.connect(host="localhost", port=65432, database="postgres", user="postgres", password="mysecretpassword")

# %% [markdown]
# Далее создаем курсор для отправки запросов и получения результатов.

# %%
cur = con.cursor()

# %% [markdown]
# Выполним несложный запрос при помощи функции execute - выбрать все поля и все записи из таблицы articles.
#
# SELECT отвечает за выборку данных. * означает, что мы выбираем все поля, но здесь можно написать конкретные поля через запятую. Поля могут содержать имя таблицы, например, articles.id_article. После FROM идут таблицы, из которых делается выборка (не забываем указать схему).

# %%
cur.execute("SELECT * FROM lenta_ru.articles")

# %% [markdown]
# Далее надо выбрать данные из курсора. Курсор не сможет отправить следующий запрос, если в нем остались не выбранные данные.

# %%
res = cur.fetchall()

# %%
res
# Out:
# [(12,
#   '«Люди не признают других машин» Как тайно попавшие в\xa0СССР японские автомобили захватили восток России? ',
#   datetime.date(2021, 11, 1),
#   'Мир узнал о дрифте в 2006 году, после выхода на экраны фильма «Тройной форсаж: Токийский дрифт». Зрители со всего света были шокированы этим таинственным японским искусством. Вот только мало кто знал, что к тому времени им владели не только жители Страны восходящего солнца, но и бывалые стритрейсеры Владивостока. Всему виной\xa0— уникальный автомобильный мир, за много лет до этого возникший на Дальнем Востоке, мир со своими легендами, героями, языком, традициями и особым колоритом. Еще во времена Советского Союза сюда тайно поставляли первые иномарки сотрудники торгового флота. С тех пор машина для жителя Дальнего Востока\xa0— больше чем просто средство передвижения. Ничего удивительного, что новый гоночный стиль и вся JDM-культура, переведенная на русский как «культура правого руля», осели именно тут. Не мосты, не архитектура, а японские праворульные тачки\xa0— вот истинное лицо сегодняшнего Владивостока. О том, как это произошло, рассказывает первая часть спецпроекта «Русский форсаж».\nВладивосток выделяется на фоне других российских городов своим необычным расположением и рельефом. Будто бы какой-то огромный великан на заре времен обхватил эту местность двумя пальцами и вытянул из мягкого, как тесто, материка в море. Там, где был один палец, появился Амурский залив, на месте второго\xa0— Уссурийский. А та часть, за которую великан держался, оторвалась и превратилась в несколько островов-осколков, крупнейший из которых\xa0— Русский.\nМестные жители гордо сравнивают Владивосток с Сан-Франциско.\n«Причудливых форм сопки, улочки, почти отвесно карабкающиеся по ним. А уж океанская гладь и вовсе роднит наши города»,\xa0— пишет профессор ДВФУ, доктор исторических наук Амир Хисамутдинов.\nРодства заметно прибавилось с появлением в 2012 году нескольких исполинских размеров мостов. Мост «Золотой» через бухту Золотой Рог стал главной архитектурной доминантой центральной части Владивостока. Высота его опор такая же, как у визитной карточки Сан-Франциско\xa0— моста «Золотые ворота»,\xa0— почти 230 метров, что всего на несколько метров ниже главного здания МГУ в Москве. А опоры моста к острову Русский, кстати, еще на сотню метров выше\xa0— как две Эйфелевы башни.\nЕще больше сходства между Владивостоком и Сан-Франциско обнаруживается в истории. Обе эти территории были присоединены к своим странам путем переговоров только в середине XIX века.\nОба города возникли как военные форты, а в конце XIX\xa0— начале ХХ века стали активно развиваться как прогрессивные мультикультурные портовые города, на улицах которых люди разговаривали на десятках языков.\nИсторический центр Владивостока\xa0— это не избы или купеческие усадьбы, а самые современные к тому времени по архитектуре и по назначению многоэтажные доходные, торговые дома, железнодорожный вокзал в неорусском стиле, лютеранский и католический храмы. Почти над всеми этими зданиями трудился забытый на долгие годы архитектор Владимир Плансон, эмигрировавший после Гражданской войны, как и тысячи других, в тот самый Сан-Франциско.\n\n«Именно у него появился первый в городе автомобиль»,\xa0— рассказывает издатель Александр Колесов. Судя по найденным им фотографиям, это был Ford Model T.\nОднако не мосты, не архитектура, а японские праворульные тачки, стоящие рядком на крутом склоне,\xa0— вот истинное лицо сегодняшнего Владивостока.\nНа 600 тысяч жителей здесь приходится 300 тысяч машин.\nТоже вполне себе по-американски.\n«Владивостокцы предпочитают двигаться исключительно на своих авто или такси, поэтому с тротуарами и вообще инфраструктурой для пешеходов в городе обстоят дела не очень»,\xa0— сетует Василий Авченко, автор книги «Правый руль».\nЗато в городе куча точек, куда можно подъехать, чтобы купить кофе, бургер и даже суп, не выходя из машины. Такого нет ни в Москве, ни в Питере.\nОднако водителям из западных регионов страны стоит знать, что эта инфраструктура\xa0— не для них. Абсолютное большинство машин во Владивостоке с правым рулем, поэтому и окошки точек с общепитом расположены справ ...
#   3,
#   ''),
#  (13,
#   'Возвращение великих. «Король тигров», Декстер и\xa0шальная Екатерина II\xa0в главных сериалах ноября',
#   datetime.date(2021, 11, 1),
#   'Увеселительные заведения по всей России снова закрываются на карантин, а это значит, что лучшим времяпрепровождением в ноябрьские праздники (и, скорее всего, весь последующий месяц) остается запойный просмотр сериалов. К счастью, стриминговые сервисы подготовили для нас массу интригующих новинок и сиквелов — от нового супергеройского проекта Marvel с Джереми Реннером и второго сезона «Великой» с Эль Фаннинг до долгожданной документалки Питера Джексона про The Beatles и продолжений «Короля тигров» и «Полезных советов» фрика-документалиста Джона Уилсона. Главные сериалы ноября — в ежемесячной подборке «Ленты.ру».\n«Декстер: Новая кровь» / Dexter: New Blood\nПродолжение-перезапуск сериала про главного американского психопата (после Патрика Бэйтмена, конечно) разворачивается через десятилетие после событий восьмого сезона шоу, вышедшего в 2013-м. Декстер Морган (Майкл С. Холл) живет под новым именем на севере США, пытаясь забыть кровавое прошлое, однако из-за серии убийств в его городке персонажу приходится взяться за старое. «Декстера» совсем недавно объявили одним из величайших сериалов XXI века, так что неудивительно, что шоу обзавелось и продолжением. Правда, новая часть заявлена как мини-сериал (то есть сиквела, скорее всего, не предусматривает) — вероятно, соскучившихся по Декстеру фанатов ждет, наконец, настоящий финал.\n«Новая кровь» будет состоять из всего четырех серий, премьера первой — 8 ноября на Showtime и в «Амедиатеке»\n«Психиатр по соседству» / The Shrink Next Door\nЗапрет на дружбу с клиентами — одно из главных правил психологов, психиатров и психотерапевтов. О том, что бывает, когда твой лечащий врач становится близким приятелем, рассказывает черная комедия «Психиатр по соседству». Шоу посвящено манипулятивным и созависимым отношениям пациента (Уилл Феррелл) с его психиатром (Пол Радд), который не только завязывает с ним тесную дружбу, но даже берется управлять его бизнесом. Учитывая звездный состав (в сериале также снялись Кэтрин Хан и Кейси Уилсон) и то, что сценаристкой проекта выступила работавшая над «Вице-президентом» и «Наследниками» Джорджия Притчетт, а режиссерами — Майкл Шоуолтер («В поиске») и Джесси Перетц («Девочки»), сериал точно не стоит пропускать.\n«Психиатр по соседству» будет состоять из восьми серий, первые три выйдут 13 ноября на Apple TV+\n«Соколиный глаз» / Hawkeye\nНе успел последний супергеройский телепроект Marvel «Что если?..» подойти к концу, как у Disney вновь поспел очередной сериал — на этот раз про одного из легендарных мстителей, Соколиного Глаза (Джереми Реннер), у которого неожиданно появляется «стажерка» Кейт Бишоп (Хейли Стейнфилд), также мастерски управляющаяся с луком и стрелами. Шоураннером выступил Джонатан Игла, сценарист «Безумцев» и «Бриджертонов». Судя по трейлеру, в котором Соколиный Глаз и его новоприобретенный сайдкик устраивают хаос в украшенном гирляндами Нью-Йорке, поклонников франшизы «Мстители» ждет самый рождественский сериал Marvel из всех увидевших свет.\n«Соколиный Глаз» будет насчитывать шесть эпизодов, два первых выйдут 25 ноября на Disney+\n«Король тигров: Убийство, хаос и безумие» / Tiger King 2\nОдин из ранних мировых хитов сервиса Netflix возвращается с неожиданным продолжением (аккурат к новому карантину). Абсурдное документальное шоу посвящено многочисленным частным зоопаркам в США — пока не ясно, на чем именно сфокусируется сериал во второй части, учитывая, что звезда первого сезона, полиаморный гей-музыкант и тигровладелец Джо Экзотик ныне отбывает наказание в тюрьме за попытку нанять киллеров для убийства зоозащитницы Кэрол Баскин. К слову, сама Баскин в ноябре выпускает собственный документальный сериал Cage Fight, посвященный ее расследованию нарушений в зоопарке Экзотика. Будто и не проходили эти долгие полтора года!\nВторой сезон «Короля тигров» целиком выйдет на Netflix 18 ноября, а реалити-шоу Кэрол Баскин будет выходит на Discovery+ c 14-го числа\nThe Sex Lives of College Girls («Сексуальная жизнь студенток»)\n«Молодой Сталин — красавч ...
#   4,
#   'В новом месяце зрителей ждет масса телевизионных новинок от нового проекта Marvel с Джереми Реннером и продолжения «Великой» с Эль Фаннинг до документалки Питера Джексона про The Beatles и второго сезона «Полезных советов» фрика-документалиста Джона Уилсона. Главные сериалы ноября — в ежемесячной подборке «Ленты.ру».'),
#  (14,
#   'Бастрыкин взял под контроль расследование убийства двух сестер в\xa0Туве',
#   datetime.date(2021, 11, 1),
#   'Глава Следственного комитета Александр Бастрыкин взял под контроль расследование убийства двух сестре 9 и 14 лет в городе Кызыле республики Тува. Об этом сообщается на сайте СК.\nПоручение доложить обо всех обстоятельствах происшествия было дано исполняющему обязанности руководителя следственного управления Геннадию Кюрю. Ход расследования уголовного дела поставлен на контроль в центральном аппарате Следкома.\nОб убийстве девочек 9 и 14 лет в Кызыле стало известно ранее в воскресенье, 31 октября. Их тела со множественными травмами обнаружили на улице, младшая скончалась на месте, а старшая умерла в больнице.\nПо предварительным данным, мужчина, снимавший комнату в их квартире, сбросил девочек с балкона. В ночь на 31 октября у него случился конфликт с детьми, которые якобы шумели и мешали ему.',
#   5,
#   'Глава Следственного комитета Александр Бастрыкин взял под контроль расследование убийства двух сестре 9 и 14 лет в городе Кызыле республики Тува. Поручение доложить обо всех обстоятельствах происшествия было дано исполняющему обязанности руководителя следственного управления Геннадию Кюрю.'),
#  (15,
#   'Байден дал совет России по\xa0добыче нефти',
#   datetime.date(2021, 11, 1),
#   'Президент США Джо Байден дал совет по добыче нефти, заявил, что отказ России и Саудовской Аравии наращивать нефтедобычу был бы неправильным. Его слова приводит РИА Новости.\n«Я думаю, что идея о том, что Россия, Саудовская Аравия и другие основные производители не будут выкачивать больше, чтобы у людей был бензин, чтобы добраться до работы и назад, неправильная», — заявил американский лидер на пресс-конференции по итогам саммита G20.\nРанее Байден на пресс-конференции по итогам саммита по климату в Риме заявил, что его разочаровал тот факт, что лидеры стран России и Китая Владимир Путин и Си Цзиньпин отсутствовали на встрече «Большой двадцатки».\nОн обратил внимание на то, что страны-участники саммита добились значительного прогресса в обсуждаемых вопросах, подчеркнув при этом, что необходимо прилагать больше усилий. Американский президент отметил, что такие усилия потребуют сосредоточения на том, чего не делают Россия, Китай и Саудовская Аравия.',
#   5,
#   'Президент США Джо Байден дал совет по добыче нефти, заявил, что отказ России и Саудовской Аравии наращивать нефтедобычу был бы неправильным. «Россия, Саудовская Аравия и другие основные производители не будут выкачивать больше, чтобы у людей был бензин, чтобы добраться до работы и назад, неправильная», — сказал он.'),
#  (16,
#   'Байден объяснил рекордное падение своих рейтингов',
#   datetime.date(2021, 10, 31),
#   'На пресс-конференции по итогам саммита G20 президент США Джо Байден прокомментировал рекордное падение своих рейтингов. Он заявил, что не обращает внимание на результаты социальных опросов и не нуждается в социальном одобрении, сообщает РИА Новости.\nБайден объяснил, что рейтинги могут как падать, так и расти. По его словам, сначала они показывали более высокие результаты, затем рухнули до середины и снова поднялись, потом опустились.\n«Со всеми другими президентами это случалось, но я не поэтому избирался, не для того, чтобы определять, как я работаю по опросам. Я избирался, чтобы быть уверенным, что смогу исполнить в качестве президента США то, что обещал», — подчеркнул американский лидер.\nПолитик добавил, что США получили существенную поддержку на саммите G20. «США — самая критически важная часть всей повестки дня», — заявил Байден.\nРанее стало известно, что одобрение деятельности Байдена рекордно упало. Популярность политика за девять месяцев его нахождения на должности снизилась сильнее, чем рейтинг любого другого лидера страны со времен Второй мировой войны. Так, президентский рейтинг Байдена снизился на 11,3 процентных пункта — с 56 процентов до 44,7 процента.',
#   5,
#   'Президент США Джо Байден прокомментировал рекордное падение своих рейтингов. Он заявил, что не обращает внимание на результаты социальных опросов. Байден отметил, что рейтинги могут как падать, так и расти. По его словам, сначала они показывали более высокие результаты, затем рухнули до середины и снова поднялись, пот<br />'),
#  (17,
#   'Медведев обвинил Европу в «пещерной логике» во\xa0время пандемии',
#   datetime.date(2021, 11, 1),
#   'Национальный эгоизм и попытки защитить собственные геополитические интересы во время пандемии в Европе иногда оказывались сильнее общечеловеческих ценностей, заявил заместитель председателя Совбеза России Дмитрий Медведев, пишет «Российская газета».\nПо словам политика, пандемия выявила разрозненность европейских стран перед лицом общей беды. По его словам, Европа никак не отреагировала на призывы к солидарности и взаимопомощи, просьбам отменить санкции, мешающие работе медиков, а также предложениям прекратить огонь в «горячих точках».\n«Национальный эгоизм, "пещерная логика" времен холодной войны, параноидальные фантомные страхи, попытки защитить собственные, узкие геополитические интересы сплошь и рядом оказывались гораздо сильнее общечеловеческих ценностей», — обвинил политик Европу.\nРанее Медведев заявил, что Россия с весны 2021 года находится в пятой фазе пандемии коронавируса, во время которой наблюдается очередной подъем заболеваемости. ',
#   6,
#   'Заместитель председателя Совбеза России Дмитрий Медведев рассказал, что пандемия показала разрозненность европейских стран. «Национальный эгоизм, "пещерная логика" времен холодной войны оказывались гораздо сильнее общечеловеческих ценностей», — подчеркнул он. <br />'),
#  (18,
#   'На Украине признали провалы в\xa0дипломатии',
#   datetime.date(2021, 11, 1),
#   'Лидер украинской «Радикальной партии» Олег Ляшко в эфире телеканала «НАШ» признал, что у границ страны нет ни одного дружественного ей государства из-за слабой дипломатии.\n«Я считаю, что у нас очень слабая дипломатия, у нас провалы на всех фронтах. Посмотрите по границам Украины — везде горит, вы не найдете ни одного дружественного государства. Румыния претендует на нашу территорию, Венгрия подписывает контракт на поставку газа в обход Украины и я уже не говорю о посягательствах на Закарпатье. Белоруссия — это фактически новый второй фронт, в Молдавии похитили Чауса», — заявил политик.\nПо его мнению, дипломатические провалы происходят из-за того, что страной управляет слабая и некомпетентная власть. Он отметил, что в национальных интересах Украины иметь у своих границ дружественные государства, в связи с чем он предложил научиться находить общие интересы с другими странами, чтобы делать из врагов друзей.\nРанее посольство США в Киеве поздравило Украину с Хеллоуином, опубликовав видео одного дня работы дипмиссии с «ужасами» ее работы. На одном из кадров, в частности, сотрудники передают друг другу папку с материалами о «российской дезинформации».',
#   5,
#   'Лидер украинской «Радикальной партии» Олег Ляшко заявил, что у страны очень слабая дипломатия, из-за который имеются провалы на всех фронтах. Также он признал, что у границ страны нет ни одного дружественного ей государства и посоветовал предпринять действия, чтобы превратить своих врагов в друзей.'),
#  (19,
#   'Кадыров рассказал о\xa0поощрении для победивших на\xa0турнире UFC бойцов «Ахмата»',
#   datetime.date(2021, 11, 1),
#   'Глава Чечни Рамзан Кадыров в Instagram оценил выступление российских бойцов смешанного стиля (MMA) Магомеда Анкалаева и Альберта Дураева на турнире UFC 267.\nКадыров посчитал, что спортсмены показали прекрасную технику, доказав, что «Ахмат» готовит лучших бойцов. Он рассказал, что отдельно поощрит Анкалаева и Дураева за достойный результат на UFC 267. «Уверен, это послужит для них дополнительным стимулом в дальнейшей спортивной карьере», — подчеркнул политик.\nНа UFC 267 Анкалаев судейским решением одолел Волкана Оздемира, Дураев победил Романа Копылова судейским решением. На счету Анкалаева теперь 16 побед и одно поражение, в активе Дураева 15 побед и три поражения.\nТурнир UFC 267 прошел в Абу-Даби 30 октября. В главном поединке вечера бразилец Гловер Тейшейра одержал победу над  поляком Яном Блаховичем с помощью удушающего приема и завоевал пояс чемпиона UFС в полутяжелом весе.',
#   7,
#   'Глава Чечни Рамзан Кадыров оценил выступление российских бойцов смешанного стиля (MMA) Магомеда Анкалаева и Альберта Дураева на турнире UFC 267. Он рассказал, что отдельно поощрит Анкалаева и Дураева за достойный результат на UFC 267. «Уверен, это послужит для них дополнительным стимулом», — подчеркнул политик. '),
#  (20,
#   'Ставки по\xa0вкладам в\xa0России превысили восемь процентов годовых',
#   datetime.date(2021, 11, 1),
#   'Ставки по вкладам в России превысили восемь процентов годовых на фоне роста ключевой ставки Центробанка до 7,5 процентов. Об этом сообщает «Коммерсантъ».\nОтмечается, что таким образом они могут догнать инфляцию, которая по итогам октября может составить не менее восьми процентов. О росте доходности по вкладам заявили сразу несколько банков из топ-50. При этом речь идет только о новых размещениях средств и не касается прежних накопительных счетов.\n«Предложение повышенных ставок позволяет банкам, испытывающим недостаток ликвидности, привлекать средства, не переплачивая за уже размещенные в этом банке деньги. Также подобные предложения могут работать на удержание поступающих средств, что особенно актуально в конце года, когда происходят выплаты бонусов», — разъяснили в Райффайзенбанке.\nЭксперты порекомендовали не торопиться закрывать действующие вклады, чтобы успеть получить повышенную ставку, и спрогнозировали, что в ближайшие два года снижение не ожидается. Кроме того, предполагается, что на фоне роста инфляции ЦБ продолжит повышать ключевую ставку.\nРанее стало известно, что в России средняя ставка по ипотечным кредитам выросла в октябре на 0,3 процентных пункта, по потребительским — на один пункт. Повышение обусловлено ростом ключевой ставки Центробанка (ЦБ). На конец октября средняя минимальная ставка на потребительские займы составляет 9,36 процента, средняя максимальная — 17,53 процента.',
#   5,
#   'Ставки по вкладам в России превысили восемь процентов годовых на фоне роста ключевой ставки Центробанка до 7,5 процентов. Отмечается, что таким образом они могут догнать инфляцию, которая по итогам октября может составить не менее восьми процентов. При этом речь идет только о новых размещениях средств.'),
#  (21,
#   'Эндокринолог перечислил способы восполнить дефицит витамина D',
#   datetime.date(2021, 11, 1),
#   'При непереносимости витамина D его можно получить из продуктов питания, а также других препаратов и с помощью всевозможных косметологических процедур, заявил врач-эндокринолог, диетолог Михаил Гинзбург, пишет «Вечерняя Москва».\nКак уточнил медик, как таковых альтернатив витаминному комплексу нет, этот микроэлемент является уникальным. Витамин D помогает организму бороться с опасными вирусами, а также предотвращает старение кожи. Он влияет на эндокринную систему, иммунитет и половые функции человека. Аллергических реакций на него не бывает, так как гормон вырабатывается самим организмом.\nКроме масляных растворов, способы пополнить дефицит витамина D — посещение солярия или прием солнечных ванн. Не стоит ходить туда часто, так как это может вызвать рак. «Люди, которые от природы смуглы, не будут получать в достаточном количестве "солнечный гормон"», — добавил он.\nВосполнить запас витамина в организме поможет включение в рацион печени трески, жирных сортов рыбы, яичного желтка и молока повышенной жирности. Из медикаментозных альтернатив врач рекомендует водорастворимые формы витамина D, к ним относится «Колекальциферол». «Не составит труда найти в аптеке специальные спреи с витамином D. Содержимое баллончика наносится под язык — и дневная доза полезного элемента пополнена», — перечислил он.\nРанее ученые заявили, что витамин D может быть опасен при борьбе с коронавирусом. При слишком большой дозировке повышается уровень кальция в крови, что, в свою очередь, провоцирует образование тромбов.',
#   6,
#   'Врач-эндокринолог, диетолог Михаил Гинзбург рассказал, как можно восполнить дефицит витамина D в организме. Из медикаментозных альтернатив врач рекомендует водорастворимые формы витамина D, к ним относится «Колекальциферол». «Не составит труда найти в аптеке специальные спреи с витамином D», — отметил он.')]

# %% [markdown]
# Итак, у нас получилось. Хотя это из-за того, что я уже что-то положил в таблицу.
#
# Теперь посмотрим как можно добавлять записи при помощи INSERT INTO.

# %%
cur.execute("INSERT INTO lenta_ru.articles (title, date, article, id_author, abstract) VALUES ('bla-bla-bla', date(now()),'bla333-bla-bla',0,'John Doe'), ('bla-bla-bla', date(now()),'bla333-bla-bla333',0,'John Doe')")

# %% [markdown]
# После изменений данных необходимо подтвердить при при помощи функции соединения `commit` или откатить назад при помощи `rollback()`. Если изменения не подтвердить, СУБД откатит их автоматически по истечении таймаута.

# %%
con.commit()

# %%
con.rollback()

# %% [markdown]
# Теперь загрузим статьи с сайта lenta.ru и положим их в базу.

# %%
# Класс, хранящий информацию о статье.
class LentaArticle:
    def __init__(self):
        self.date = ""
        self.author = ""
        self.head = ""
        self.text = ""
        self.abstract = ""
    
def getArticleLenta(adr: str) -> LentaArticle:
    ''' Загружает с сайта lenta.ru все статью, задаваемую http-адресом adr.
    '''
    page = requests.get(adr)
    #print(r.text)
    art = LentaArticle()
    
    tree = html.fromstring(page.text)
    art.head = tree.xpath(".//h1")[0].text_content()
#     art.date = tree.xpath(".//div[@class='b-topic__info']//time")[0].text_content().strip()
    art.date = '.'.join(adr.split('/')[4:7])
    art.author = tree.xpath(".//span[@itemprop='name']")[0].text_content().strip()
    try:
        art.abstract = tree.xpath(".//meta[@itemprop='description']")[0].get("content")
    except:
        art.abstract = ''

    art.text = '\n'.join([p.text_content() for p in tree.xpath(".//div[@itemprop='articleBody']/p")])
    
    return art

def getDayArticles(adr: str) -> list[LentaArticle]:
    ''' Загружает с сайта lenta.ru все статьи за день, задаваемый http-адресом adr.
    '''
    articles = []
    day = requests.get(adr)
    tree = html.fromstring(day.text)
    body = tree.xpath(".//a[@class='titles']")
    links = ['https://lenta.ru' + x.attrib["href"] for x in body]
    for link in links[:10]: # идем по первым 10 ссылкам на новости за день.
        print(link)
        art = getArticleLenta(link)
        if art.text != '':
            articles.append(art)
            
    return articles

def insertLentaArticle(art: LentaArticle, cur, con):
    ''' Функция кладет статью в базу данных.
        Предварительно проверяется наличие автора статьи в таблице authors. 
        Если его там нет, он кладется в таблицу.
    '''
    # Ищем автора и его id.
    cur.execute(f"SELECT id_author FROM lenta_ru.authors WHERE name='{art.author}'")
    authors = cur.fetchall()
    if len(authors) == 0: # Если автора нет - добавим его.
        cur.execute(f"INSERT INTO lenta_ru.authors (name, comment) VALUES ('{art.author}', '')")
        con.commit()
        cur.execute(f"SELECT id_author FROM lenta_ru.authors a WHERE a.name='{art.author}'")
        authors = cur.fetchall()
        
    id_author = authors[0][0]
    # Заменим апострофы, которые являются специальным символом для SQL на \'
    head = art.head.replace("'", "\\'")
    text = art.text.replace("'", "\\'")
    abstract = art.abstract.replace("'", "\\'")
    
    req = f"INSERT INTO lenta_ru.articles (title, date, article, id_author, abstract) VALUES " \
          f"('{head}', date('{art.date}'), '{text}', {id_author}, '{abstract}')"
    cur.execute(req)
    con.commit()

# %% [markdown]
# Достанем статьи с сайта.

# %%
arts = getDayArticles("https://lenta.ru/2021/11/01/")
# Out:
# https://lenta.ru/articles/2021/11/01/rf1/
# https://lenta.ru/articles/2021/11/01/noveseries/
# https://lenta.ru/news/2021/11/01/bastrykin_tuva/
# https://lenta.ru/news/2021/11/01/advice/
# https://lenta.ru/news/2021/10/31/record/
# https://lenta.ru/news/2021/11/01/medvedev_europe/
# https://lenta.ru/news/2021/11/01/diplomacy/
# https://lenta.ru/news/2021/11/01/kadyrov/
# https://lenta.ru/news/2021/11/01/stavki_vklady/
# https://lenta.ru/news/2021/11/01/endocrinologist/

# %% [markdown]
# Посмотрим что вообще загружается.

# %%
arts[0].head
# Out:
# '«Люди не признают других машин» Как тайно попавшие в\xa0СССР японские автомобили захватили восток России? '

# %%
arts[0].abstract
# Out:
# ''

# %%
arts[0].author
# Out:
# 'Сергей Лютых'

# %%
for art in arts:
    insertLentaArticle(art, cur, con)

# %% [markdown]
# ### Краткий экскурс в скачивание сайтов
#
# `requests` - библиотека для отправки http-запросов.
# `lxml` - библиотека для работы с XML и HTML.
#
# **XPath**
# [Ссылка 1](https://habr.com/ru/post/526774/)
# [Ссылка 2](https://habr.com/ru/post/464897/)
#
# XPath позволяет задать шаблон для пути от корня XML-дерева к интересующей нас вершине.
#
# - . - корень XML-дерева
# - / - переход на один уровень ниже.
# - // - переход на ноль или больше уровней вниз.
# - \* - любая вершина.
# - xyz - название вершины.
# - [@feature] - вершина с параметром feature.
# - [@feature='111'] - вершина с параметром feature, равным "111".
# - xyz[n] - n-ый потомок вершины xyz.

# %% [markdown]
# ### Пару слов о безопасности
#
# ![](https://imgs.xkcd.com/comics/exploits_of_a_mom.png)
#
# Вот так гораздо лучше.
#
# ```Python
# req = f"INSERT INTO lenta_ru.articles (title, date, article, id_author, abstract) VALUES " \
#       f"(%s, date(%s), %s, %d, %s)"
# cur.execute(req, (head, art.date, text, id_author, abstract))
# con.commit()
# ```
#
# Заодно не надо будет заменять апострофы (и кое-что ещё).

# %%
def insertLentaArticle2(art: LentaArticle, cur, con):
    ''' Функция кладет статью в базу данных.
        Предварительно проверяется наличие автора статьи в таблице authors. 
        Если его там нет, он кладется в таблицу.
    '''
    # Ищем автора и его id.
    cur.execute(f"SELECT id_author FROM lenta_ru.authors WHERE name='{art.author}'")
    authors = cur.fetchall()
    if len(authors) == 0: # Если автора нет - добавим его.
        cur.execute(f"INSERT INTO lenta_ru.authors (name, comment) VALUES ('{art.author}', '')")
        con.commit()
        cur.execute(f"SELECT id_author FROM lenta_ru.authors a WHERE a.name='{art.author}'")
        authors = cur.fetchall()
        
    id_author = authors[0][0]

    req = f"INSERT INTO lenta_ru.articles (title, date, article, id_author, abstract) VALUES " \
          f"(%s, date(%s), %s, %s, %s)"
    cur.execute(req, (art.head, art.date, art.text, id_author, art.abstract))
    con.commit()

# %%
for art in arts:
    print(art.head)
    insertLentaArticle2(art, cur, con)
# Out:
# «Люди не признают других машин» Как тайно попавшие в СССР японские автомобили захватили восток России?
# Возвращение великих. «Король тигров», Декстер и шальная Екатерина II в главных сериалах ноября
# Бастрыкин взял под контроль расследование убийства двух сестер в Туве
# Байден дал совет России по добыче нефти
# Байден объяснил рекордное падение своих рейтингов
# Медведев обвинил Европу в «пещерной логике» во время пандемии
# На Украине признали провалы в дипломатии
# Кадыров рассказал о поощрении для победивших на турнире UFC бойцов «Ахмата»
# Ставки по вкладам в России превысили восемь процентов годовых
# Эндокринолог перечислил способы восполнить дефицит витамина D

# %%
len(arts)
# Out:
# 10
